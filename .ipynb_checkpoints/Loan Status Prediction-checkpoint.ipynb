# %% [markdown]
# To-do:
# * Update table of contents
# * Write introduction
# * Write conclusion
# * More EDA?

# %% [markdown]
# # Loan Status Prediction: Lending Club, 2007-2017
#
# ***By Joe Corliss***

# %% [markdown]
# ## Table of Contents
#
# 1. [Summary](#1)
#     1. [Spoilers](#1.1)

# %% [markdown]
# # Introduction

# %% [markdown]
# [Dataset 1](https://www.kaggle.com/wordsforthewise/lending-club) - The dataset used in this project, hosted on Kaggle
#
# [Dataset 2](https://www.kaggle.com/wendykan/lending-club-loan-data) - Another Lending Club dataset on Kaggle, not used in this project
#
# [Kaggle notebook](https://www.kaggle.com/pileatedperch/predicting-loan-status-mcc-0-73) - This notebook on Kaggle
#
# [Lending Club statistics](https://www.lendingclub.com/info/download-data.action) - Original data source
#
# [GitHub repository](https://github.com/jgcorliss/lending-club) - This project on GitHub
#
# The goal of this project is to predict loan charge-offs using only data available on the loan application.

# %% [markdown]
# # Import the Data
# <a id="2"></a>

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Pandas options
pd.set_option('display.max_colwidth', 1000, 'display.max_rows', None, 'display.max_columns', None)

# Plotting options
# %matplotlib inline
mpl.style.use('ggplot')
sns.set(style='whitegrid')

# %% [markdown]
# Read in the data.

# %%
loans = pd.read_csv('accepted_2007_to_2017Q3.csv.gz', compression='gzip')
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (0,18,48,58,117,128,129,130,133,134,135,138,144,145,146) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Check basic dataframe info.

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1646801 entries, 0 to 1646800
# Columns: 150 entries, id to settlement_term
# dtypes: float64(113), object(37)
# memory usage: 1.8+ GB

# %% [markdown]
# Sample some rows:

# %%
loans.sample(100)
# Out:
#                 id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 825766     8865572        NaN    10800.0      10800.0          10750.0
# 820796     8627917        NaN    28000.0      28000.0          28000.0
# 1058315   96750572        NaN    10000.0      10000.0          10000.0
# 370430    63404612        NaN    10800.0      10800.0          10800.0
# 290301    67695643        NaN     2500.0       2500.0           2500.0
# 59514     29263796        NaN    26400.0      26400.0          26400.0
# 1632184   68745355        NaN    16275.0      16275.0          16275.0
# 649679    40931317        NaN    19000.0      19000.0          19000.0
# 232195    10172059        NaN    16800.0      16800.0          16800.0
# 384479    62053039        NaN    24000.0      24000.0          24000.0
# 1477940   91228683        NaN     2525.0       2525.0           2525.0
# 1159859   85725510        NaN     6450.0       6450.0           6450.0
# 875028     6329328        NaN     9600.0       9600.0           9600.0
# 1255627  115352577        NaN    12000.0      12000.0          11975.0
# 963952     1488650        NaN    11200.0      11200.0          11200.0
# 697652    36078934        NaN     6300.0       6300.0           6300.0
# 331272    65591892        NaN    24000.0      24000.0          24000.0
# 1144300   86943040        NaN     9000.0       9000.0           9000.0
# 1081105   96300282        NaN    12000.0      12000.0          12000.0
# 737831   110076339        NaN    12000.0      12000.0          12000.0
# 620501    42295275        NaN    24450.0      24450.0          24450.0
# 591366    46417019        NaN    18000.0      18000.0          18000.0
# 674340    39570334        NaN    21000.0      21000.0          21000.0
# 1229860  117870332        NaN    11500.0      11500.0          11500.0
# 77196     27410301        NaN    30000.0      30000.0          30000.0
# 1316669   83656340        NaN    12000.0      12000.0          12000.0
# 932642     3195915        NaN    23000.0      23000.0          23000.0
# 608512    44663312        NaN    10175.0      10175.0          10175.0
# 927721     3294212        NaN    23000.0      23000.0          23000.0
# 956345     1578735        NaN     6000.0       6000.0           6000.0
# 969697     1409821        NaN    18000.0      18000.0          18000.0
# 315932    66016543        NaN    15000.0      15000.0          15000.0
# 1016862  100459379        NaN    40000.0      40000.0          40000.0
# 413166    60666955        NaN    12000.0      12000.0          12000.0
# 306670    66562847        NaN    12000.0      12000.0          12000.0
# 1565306   73366272        NaN    25000.0      25000.0          25000.0
# 850313     7336980        NaN     6625.0       6625.0           6625.0
# 287253    67829194        NaN    15000.0      15000.0          15000.0
# 224054    10766253        NaN    15000.0      15000.0          15000.0
# 209311    12245150        NaN     9925.0       9925.0           9925.0
# 1326918   79563890        NaN    30000.0      30000.0          30000.0
# 649108    41011498        NaN    35000.0      35000.0          35000.0
# 1288649  113535126        NaN     6000.0       6000.0           6000.0
# 1181953   84475182        NaN    15000.0      15000.0          15000.0
# 412849    60780366        NaN    12000.0      12000.0          12000.0
# 513939    53944126        NaN    18000.0      18000.0          18000.0
# 583777    46724232        NaN    12000.0      12000.0          11900.0
# 1270565  113386700        NaN     5000.0       5000.0           5000.0
# 1017861   99877565        NaN    10500.0      10500.0          10500.0
# 396552    61399140        NaN    35000.0      35000.0          35000.0
# 1111930   88922367        NaN     5000.0       5000.0           5000.0
# 181149    13887861        NaN     3000.0       3000.0           3000.0
# 1644244   68340878        NaN     9600.0       9600.0           9600.0
# 1478498   92224870        NaN     7200.0       7200.0           7200.0
# 436674    58733138        NaN    30000.0      30000.0          30000.0
# 1221448  118005699        NaN    12000.0      12000.0          12000.0
# 856049     7154601        NaN     5000.0       5000.0           5000.0
# 908350     4384641        NaN    11000.0      11000.0          11000.0
# 598920    45584248        NaN     8500.0       8500.0           8500.0
# 1065766   96766593        NaN     5600.0       5600.0           5600.0
# 224479    10576967        NaN     8000.0       8000.0           8000.0
# 600328    43649349        NaN    12050.0      12050.0          12050.0
# 160555    16111339        NaN    12175.0      12175.0          12175.0
# 1120716   88960740        NaN    30000.0      30000.0          30000.0
# 970405     1416373        NaN    10800.0      10800.0          10800.0
# 919740     3676548        NaN    28000.0      28000.0          28000.0
# 1023235   99255806        NaN     2525.0       2525.0           2525.0
# 655697    40594078        NaN    17000.0      17000.0          17000.0
# 233573     9706374        NaN    20000.0      20000.0          20000.0
# 493308    55073031        NaN     6000.0       6000.0           6000.0
# 1057789   97526061        NaN     9000.0       9000.0           9000.0
# 53152     30365833        NaN     7000.0       7000.0           7000.0
# 1089734   90693042        NaN    12000.0      12000.0          12000.0
# 389463    61464625        NaN    35000.0      35000.0          34975.0
# 911667     3929190        NaN    19425.0      19425.0          19425.0
# 905580     4245019        NaN    24000.0      24000.0          24000.0
# 439916    58932567        NaN     9750.0       9750.0           9750.0
# 910414     4287347        NaN     8000.0       8000.0           8000.0
# 1603547   70583167        NaN    12000.0      12000.0          12000.0
# 1254386  114500235        NaN    16000.0      16000.0          16000.0
# 319837    65944568        NaN    26000.0      26000.0          26000.0
# 1307508  111888391        NaN    20000.0      20000.0          20000.0
# 815008     9404612        NaN    24000.0      24000.0          24000.0
# 605759    44925756        NaN    27425.0      27425.0          27425.0
# 1504746   91090681        NaN     3500.0       3500.0           3500.0
# 991107     1102633        NaN    20000.0      20000.0          19700.0
# 1008060  102563824        NaN     8000.0       8000.0           8000.0
# 795618   103328397        NaN     7575.0       7575.0           7575.0
# 416714    60586177        NaN    10000.0      10000.0          10000.0
# 1566005   73469564        NaN    10000.0      10000.0          10000.0
# 12375     36098210        NaN    23025.0      23025.0          23025.0
# 718577   111109920        NaN     6500.0       6500.0           6500.0
# 534296    50436242        NaN    15000.0      15000.0          15000.0
# 645027    41002128        NaN     5500.0       5500.0           5500.0
# 381104    62266071        NaN    10000.0      10000.0           9975.0
# 1486114   91804023        NaN    24000.0      24000.0          24000.0
# 90133     24846784        NaN     5000.0       5000.0           5000.0
# 583490    46642078        NaN    20000.0      20000.0          20000.0
# 1267449  114054684        NaN    30000.0      30000.0          30000.0
# 1292967  113054954        NaN     4000.0       4000.0           4000.0
#
#                term  int_rate  installment grade sub_grade  \
# 825766    36 months     13.67       367.39     B        B5
# 820796    36 months      9.67       899.15     B        B1
# 1058315   36 months      7.49       311.02     A        A4
# 370430    60 months     18.25       275.72     E        E1
# 290301    36 months      8.38        78.78     B        B1
# 59514     60 months     16.29       646.08     D        D2
# 1632184   60 months     20.50       435.73     E        E4
# 649679    36 months      7.89       594.43     A        A5
# 232195    60 months     14.98       399.50     C        C3
# 384479    60 months     15.61       578.68     D        D1
# 1477940   36 months     18.99        92.55     D        D3
# 1159859   36 months     15.59       225.46     C        C5
# 875028    36 months     18.85       351.18     D        D3
# 1255627   36 months      7.97       375.88     A        A5
# 963952    60 months     20.49       299.80     E        E1
# 697652    36 months      8.19       197.98     A        A5
# 331272    60 months      7.89       485.38     A        A5
# 1144300   36 months      9.49       288.26     B        B2
# 1081105   36 months     11.49       395.66     B        B5
# 737831    60 months     16.02       291.95     C        C5
# 620501    36 months     15.61       854.89     D        D1
# 591366    60 months     13.33       412.61     C        C3
# 674340    60 months     13.66       484.94     C        C3
# 1229860   36 months      9.44       368.06     B        B1
# 77196     60 months     18.24       765.73     D        D5
# 1316669   36 months      9.49       384.34     B        B2
# 932642    36 months     18.75       840.19     D        D3
# 608512    36 months     14.65       350.98     C        C5
# 927721    60 months     16.29       562.87     C        C4
# 956345    36 months     16.29       211.81     C        C4
# 969697    60 months     13.11       410.57     B        B4
# 315932    36 months      7.89       469.29     A        A5
# 1016862   36 months     11.39      1316.95     B        B3
# 413166    60 months     13.33       275.07     C        C3
# 306670    60 months     13.18       274.15     C        C3
# 1565306   36 months     14.46       860.04     C        C4
# 850313    36 months     18.55       241.35     D        D2
# 287253    36 months      6.89       462.41     A        A3
# 224054    36 months     14.98       519.84     C        C3
# 209311    36 months     15.61       347.03     C        C5
# 1326918   36 months     10.75       978.62     B        B4
# 649108    36 months      7.89      1095.00     A        A5
# 1288649   36 months      9.44       192.03     B        B1
# 1181953   36 months     12.79       503.90     C        C1
# 412849    60 months     12.29       268.70     C        C1
# 513939    36 months     10.99       589.22     B        B4
# 583777    36 months      5.93       364.69     A        A1
# 1270565   36 months     10.91       163.49     B        B4
# 1017861   36 months     13.49       356.27     C        C2
# 396552    36 months     10.99      1145.69     B        B4
# 1111930   36 months     16.99       178.24     D        D1
# 181149    36 months     13.65       102.03     C        C1
# 1644244   36 months     14.85       332.09     C        C5
# 1478498   36 months     13.49       244.30     C        C2
# 436674    60 months     14.65       708.20     C        C5
# 1221448   36 months     17.09       428.38     D        D1
# 856049    36 months      9.71       160.66     B        B1
# 908350    36 months     10.16       355.77     B        B1
# 598920    36 months      6.92       262.15     A        A4
# 1065766   36 months     12.74       187.99     C        C1
# 224479    36 months      8.90       254.03     A        A5
# 600328    36 months     15.61       421.33     D        D1
# 160555    60 months     18.24       310.76     D        D5
# 1120716   36 months      6.99       926.18     A        A2
# 970405    36 months     14.33       370.86     C        C1
# 919740    60 months     16.29       685.23     C        C4
# 1023235   36 months     11.44        83.20     B        B4
# 655697    36 months      6.39       520.19     A        A2
# 233573    60 months     16.99       496.95     D        D1
# 493308    36 months      6.24       183.19     A        A2
# 1057789   36 months     15.99       316.37     C        C5
# 53152     36 months     14.99       242.63     C        C5
# 1089734   60 months     18.99       311.23     D        D3
# 389463    60 months     17.86       886.11     D        D5
# 911667    36 months     19.72       719.14     D        D5
# 905580    36 months      6.03       730.46     A        A1
# 439916    36 months      9.99       314.56     B        B3
# 910414    36 months     14.09       273.78     B        B5
# 1603547   36 months      9.16       382.50     B        B2
# 1254386   60 months     15.05       381.06     C        C4
# 319837    36 months     15.41       906.53     D        D1
# 1307508   60 months     16.02       486.58     C        C5
# 815008    36 months      7.62       747.88     A        A3
# 605759    60 months     12.69       619.66     C        C2
# 1504746   36 months      6.99       108.06     A        A2
# 991107    36 months     12.42       668.31     B        B4
# 1008060   36 months     13.49       271.45     C        C2
# 795618    36 months     28.69       316.16     F        F1
# 416714    36 months      7.26       309.97     A        A4
# 1566005   36 months     10.75       326.21     B        B4
# 12375     60 months     14.31       539.46     C        C4
# 718577    36 months     14.08       222.41     C        C3
# 534296    36 months     11.53       494.86     B        B5
# 645027    36 months     13.33       186.20     C        C3
# 381104    36 months     15.61       349.65     D        D1
# 1486114   36 months     12.74       805.66     C        C1
# 90133     36 months      8.39       157.59     A        A5
# 583490    60 months     21.67       548.64     E        E5
# 1267449   36 months     12.62      1005.34     C        C1
# 1292967   36 months     13.59       135.92     C        C2
#
#                                       emp_title emp_length home_ownership  \
# 825766                         regional manager    5 years           RENT
# 820796                                      NaN    5 years            OWN
# 1058315    TELUS Operations and Service Manager  10+ years            OWN
# 370430                                  Tier 3     3 years       MORTGAGE
# 290301                                      NaN        NaN       MORTGAGE
# 59514                         Clinical Director   < 1 year            OWN
# 1632184                              supervisor  10+ years            OWN
# 649679                      inside sales agent     3 years           RENT
# 232195       Training Instructor (DOD Civilian)    6 years       MORTGAGE
# 384479                    Applications Engineer    4 years       MORTGAGE
# 1477940                         Account Manager    7 years       MORTGAGE
# 1159859                      Corporate trainer     3 years       MORTGAGE
# 875028                           Robert Sanders   < 1 year           RENT
# 1255627           Senior clinical informaticist     1 year           RENT
# 963952                                      ATT    4 years       MORTGAGE
# 697652                         CUSTOMER SERVICE    8 years           RENT
# 331272                        Financial Analyst    3 years            OWN
# 1144300                        Machine Operator    8 years           RENT
# 1081105                                mechanic    7 years       MORTGAGE
# 737831                               Supervisor  10+ years       MORTGAGE
# 620501                           Staff Sergeant  10+ years       MORTGAGE
# 591366                       Finance Supervisor  10+ years       MORTGAGE
# 674340                               Pharmacist   < 1 year       MORTGAGE
# 1229860       Credit and collection specialist     5 years       MORTGAGE
# 77196                           Insurance Agent  10+ years           RENT
# 1316669                                 Manager    5 years           RENT
# 932642                            FIRST STUDENT  10+ years       MORTGAGE
# 608512   Project Coordinator for Physician Svcs   < 1 year       MORTGAGE
# 927721                              Wells Fargo    3 years       MORTGAGE
# 956345           Office of Personnel Management     1 year           RENT
# 969697                 In-Position Technologies   < 1 year       MORTGAGE
# 315932                   Regional Sales Manager    8 years       MORTGAGE
# 1016862             Director of Audit and Risk     2 years       MORTGAGE
# 413166                                       LO     1 year       MORTGAGE
# 306670                         Office assistant  10+ years       MORTGAGE
# 1565306                                 Foreman  10+ years            OWN
# 850313                                      NaN        NaN           RENT
# 287253                            Social Worker    5 years           RENT
# 224054                         home health aide  10+ years       MORTGAGE
# 209311               Senior Mechanical Engineer    2 years       MORTGAGE
# 1326918             Director, Helpdesk Services    2 years       MORTGAGE
# 649108                       Investment Manager    6 years       MORTGAGE
# 1288649                       Machine operator     5 years       MORTGAGE
# 1181953               Associate Project Manager  10+ years       MORTGAGE
# 412849                               Ag Ops Mgr    8 years       MORTGAGE
# 513939                        Account Executive    3 years           RENT
# 583777                          insurance agent  10+ years       MORTGAGE
# 1270565                                 trimmer    6 years       MORTGAGE
# 1017861                       Detention Officer    3 years           RENT
# 396552                        Territory Manager    3 years       MORTGAGE
# 1111930                             purchasing     4 years           RENT
# 181149                                       rn    5 years           RENT
# 1644244                      Executive Director    2 years       MORTGAGE
# 1478498                              assisstant    8 years       MORTGAGE
# 436674                   Financial Professional    3 years           RENT
# 1221448                             Nurse IC/SD  10+ years       MORTGAGE
# 856049              Polk County Clerk of Courts    6 years            OWN
# 908350                     State Bank and Trust   < 1 year       MORTGAGE
# 598920   Director of Finance and Administration    2 years           RENT
# 1065766                               Assembly     2 years            OWN
# 224479                                vice pres  10+ years       MORTGAGE
# 600328                        Logistics Manager  10+ years       MORTGAGE
# 160555                                 selector    8 years           RENT
# 1120716                          Civil Engineer    3 years            OWN
# 970405                                  Carsons    3 years       MORTGAGE
# 919740                        MCCANN INDUSTRIES  10+ years       MORTGAGE
# 1023235                    Litigation Paralegal  10+ years           RENT
# 655697                                      NaN        NaN       MORTGAGE
# 233573                         Business Analyst    2 years       MORTGAGE
# 493308           inspections/service technician    4 years            OWN
# 1057789                         Payroll Manager   < 1 year       MORTGAGE
# 53152                          District Manager  10+ years           RENT
# 1089734                                   sales    8 years       MORTGAGE
# 389463                           Chief Engineer  10+ years           RENT
# 911667                        Corporate brokers     1 year           RENT
# 905580             Florham Park Surgical Center    4 years       MORTGAGE
# 439916                               Bookkeeper  10+ years       MORTGAGE
# 910414                 Internal Revenue Service    4 years       MORTGAGE
# 1603547                                   Sales  10+ years            OWN
# 1254386                    Executive Assistant   10+ years           RENT
# 319837                         Senior Associate    2 years       MORTGAGE
# 1307508             Data Information Specialist    2 years       MORTGAGE
# 815008                     sr. ceramic engineer  10+ years       MORTGAGE
# 605759                       Operations Manager    6 years       MORTGAGE
# 1504746                          Owner/Operator  10+ years       MORTGAGE
# 991107          department of homeland security    7 years           RENT
# 1008060                 Maintenence technician      1 year           RENT
# 795618                                      NaN        NaN       MORTGAGE
# 416714                           Office Manager    6 years       MORTGAGE
# 1566005                    Social Media Manager    3 years       MORTGAGE
# 12375                        Universal Counslor    7 years           RENT
# 718577                        Chief Strategist    < 1 year           RENT
# 534296                   Regional Sales Manager    3 years       MORTGAGE
# 645027                   IT Infrastructure tech    3 years           RENT
# 381104                           electrical pro  10+ years       MORTGAGE
# 1486114                               secretary  10+ years           RENT
# 90133                                supervisor  10+ years       MORTGAGE
# 583490                            test engineer  10+ years       MORTGAGE
# 1267449                     Relationship Banker   < 1 year           RENT
# 1292967                               Carpenter     1 year           RENT
#
#          annual_inc verification_status   issue_d         loan_status  \
# 825766      49000.0            Verified  Nov-2013          Fully Paid
# 820796     120000.0     Source Verified  Dec-2013          Fully Paid
# 1058315    127000.0     Source Verified  Jan-2017          Fully Paid
# 370430      41000.0     Source Verified  Nov-2015             Current
# 290301      79000.0        Not Verified  Dec-2015             Current
# 59514       65000.0     Source Verified  Oct-2014             Current
# 1632184     70000.0        Not Verified  Jan-2016  Late (31-120 days)
# 649679     135000.0     Source Verified  Feb-2015             Current
# 232195      76000.0            Verified  Jan-2014             Current
# 384479      66000.0            Verified  Oct-2015             Current
# 1477940     40000.0     Source Verified  Nov-2016             Current
# 1159859     45000.0     Source Verified  Jul-2016             Current
# 875028      72000.0        Not Verified  Jul-2013         Charged Off
# 1255627    105000.0     Source Verified  Aug-2017             Current
# 963952      33456.0            Verified  Sep-2012          Fully Paid
# 697652      25000.0            Verified  Jan-2015          Fully Paid
# 331272      85000.0     Source Verified  Nov-2015             Current
# 1144300     65000.0     Source Verified  Aug-2016             Current
# 1081105     65000.0     Source Verified  Jan-2017          Fully Paid
# 737831      72000.0        Not Verified  May-2017             Current
# 620501      70000.0            Verified  Apr-2015         Charged Off
# 591366      62000.0        Not Verified  Apr-2015             Current
# 674340     107000.0            Verified  Jan-2015          Fully Paid
# 1229860     60000.0        Not Verified  Aug-2017             Current
# 77196      144000.0     Source Verified  Sep-2014          Fully Paid
# 1316669     70000.0        Not Verified  Jun-2016  Late (31-120 days)
# 932642      54000.0            Verified  Jan-2013          Fully Paid
# 608512      65000.0     Source Verified  Apr-2015          Fully Paid
# 927721      70000.0            Verified  Feb-2013         Charged Off
# 956345      74872.0        Not Verified  Oct-2012          Fully Paid
# 969697     118500.0     Source Verified  Aug-2012          Fully Paid
# 315932     125000.0        Not Verified  Dec-2015          Fully Paid
# 1016862    180000.0     Source Verified  Mar-2017         Charged Off
# 413166     120000.0        Not Verified  Sep-2015         Charged Off
# 306670      90000.0     Source Verified  Dec-2015             Current
# 1565306     85000.0        Not Verified  Mar-2016             Current
# 850313      22668.0            Verified  Sep-2013          Fully Paid
# 287253      65000.0        Not Verified  Dec-2015          Fully Paid
# 224054      65000.0     Source Verified  Feb-2014          Fully Paid
# 209311     131938.0     Source Verified  Feb-2014          Fully Paid
# 1326918    122000.0            Verified  Jun-2016          Fully Paid
# 649108     200000.0            Verified  Feb-2015          Fully Paid
# 1288649     40000.0        Not Verified  Jul-2017             Current
# 1181953     75000.0            Verified  Jul-2016  Late (31-120 days)
# 412849      79000.0            Verified  Oct-2015         Charged Off
# 513939      70000.0        Not Verified  Jul-2015             Current
# 583777      34000.0     Source Verified  Apr-2015             Current
# 1270565     25000.0            Verified  Aug-2017             Current
# 1017861     29500.0     Source Verified  Mar-2017             Current
# 396552     300000.0     Source Verified  Oct-2015          Fully Paid
# 1111930     42000.0            Verified  Sep-2016             Current
# 181149     100000.0        Not Verified  Apr-2014          Fully Paid
# 1644244     60000.0            Verified  Jan-2016             Current
# 1478498     40000.0     Source Verified  Nov-2016             Current
# 436674      65000.0     Source Verified  Aug-2015             Current
# 1221448    110000.0     Source Verified  Sep-2017             Current
# 856049      30200.0        Not Verified  Sep-2013          Fully Paid
# 908350      95000.0     Source Verified  Apr-2013          Fully Paid
# 598920      94000.0     Source Verified  Apr-2015          Fully Paid
# 1065766     27000.0            Verified  Jan-2017             Current
# 224479     110000.0     Source Verified  Jan-2014          Fully Paid
# 600328      75000.0     Source Verified  Apr-2015             Current
# 160555      33909.0     Source Verified  May-2014          Fully Paid
# 1120716    160000.0     Source Verified  Aug-2016             Current
# 970405      75000.0        Not Verified  Jul-2012          Fully Paid
# 919740      85000.0            Verified  Mar-2013          Fully Paid
# 1023235     66393.6            Verified  Mar-2017             Current
# 655697      44066.0            Verified  Feb-2015             Current
# 233573     112000.0     Source Verified  Jan-2014          Fully Paid
# 493308      30000.0        Not Verified  Jul-2015          Fully Paid
# 1057789     93000.0     Source Verified  Jan-2017             Current
# 53152       76000.0        Not Verified  Oct-2014          Fully Paid
# 1089734     60000.0        Not Verified  Sep-2016          Fully Paid
# 389463      82000.0            Verified  Oct-2015   Late (16-30 days)
# 911667      98000.0        Not Verified  Apr-2013          Fully Paid
# 905580     100000.0            Verified  May-2013         Charged Off
# 439916      29000.0            Verified  Aug-2015             Current
# 910414      57065.0        Not Verified  Apr-2013          Fully Paid
# 1603547    180000.0     Source Verified  Feb-2016  Late (31-120 days)
# 1254386     95000.0     Source Verified  Aug-2017             Current
# 319837      63500.0            Verified  Dec-2015          Fully Paid
# 1307508    114500.0     Source Verified  Jul-2017             Current
# 815008      87000.0     Source Verified  Dec-2013          Fully Paid
# 605759      93000.0            Verified  Apr-2015             Current
# 1504746     36000.0        Not Verified  Oct-2016             Current
# 991107      68000.0            Verified  Jan-2012          Fully Paid
# 1008060     78000.0     Source Verified  Mar-2017             Current
# 795618      22320.0            Verified  Apr-2017             Current
# 416714      62894.0        Not Verified  Sep-2015             Current
# 1566005     42250.0        Not Verified  Mar-2016             Current
# 12375       60000.0     Source Verified  Nov-2014         Charged Off
# 718577     120000.0        Not Verified  Jun-2017             Current
# 534296     126000.0     Source Verified  Jun-2015          Fully Paid
# 645027      72000.0            Verified  Feb-2015          Fully Paid
# 381104      49000.0     Source Verified  Oct-2015             Current
# 1486114     55000.0     Source Verified  Nov-2016             Current
# 90133       55000.0        Not Verified  Aug-2014          Fully Paid
# 583490     101388.0     Source Verified  Apr-2015         Charged Off
# 1267449     38000.0     Source Verified  Aug-2017             Current
# 1292967     50000.0     Source Verified  Jul-2017             Current
#
#         pymnt_plan  \
# 825766           n
# 820796           n
# 1058315          n
# 370430           n
# 290301           n
# 59514            n
# 1632184          n
# 649679           n
# 232195           n
# 384479           n
# 1477940          n
# 1159859          n
# 875028           n
# 1255627          n
# 963952           n
# 697652           n
# 331272           n
# 1144300          n
# 1081105          n
# 737831           n
# 620501           n
# 591366           n
# 674340           n
# 1229860          n
# 77196            n
# 1316669          n
# 932642           n
# 608512           n
# 927721           n
# 956345           n
# 969697           n
# 315932           n
# 1016862          n
# 413166           n
# 306670           n
# 1565306          n
# 850313           n
# 287253           n
# 224054           n
# 209311           n
# 1326918          n
# 649108           n
# 1288649          n
# 1181953          n
# 412849           n
# 513939           n
# 583777           n
# 1270565          n
# 1017861          n
# 396552           n
# 1111930          n
# 181149           n
# 1644244          n
# 1478498          n
# 436674           n
# 1221448          n
# 856049           n
# 908350           n
# 598920           n
# 1065766          n
# 224479           n
# 600328           n
# 160555           n
# 1120716          n
# 970405           n
# 919740           n
# 1023235          n
# 655697           n
# 233573           n
# 493308           n
# 1057789          n
# 53152            n
# 1089734          n
# 389463           n
# 911667           n
# 905580           n
# 439916           n
# 910414           n
# 1603547          n
# 1254386          n
# 319837           n
# 1307508          n
# 815008           n
# 605759           n
# 1504746          n
# 991107           n
# 1008060          n
# 795618           n
# 416714           n
# 1566005          n
# 12375            n
# 718577           n
# 534296           n
# 645027           n
# 381104           n
# 1486114          n
# 90133            n
# 583490           n
# 1267449          n
# 1292967          n
#
#                                                                                                                                                                                                                                                                                                                                 desc  \
# 825766                                                                                                                                                                                                                                                                                                                           NaN
# 820796                                                                                                                                                                                                                                                                                                                           NaN
# 1058315                                                                                                                                                                                                                                                                                                                          NaN
# 370430                                                                                                                                                                                                                                                                                                                           NaN
# 290301                                                                                                                                                                                                                                                                                                                           NaN
# 59514                                                                                                                                                                                                                                                                                                                            NaN
# 1632184                                                                                                                                                                                                                                                                                                                          NaN
# 649679                                                                                                                                                                                                                                                                                                                           NaN
# 232195                                                                                                                                                Borrower added on 01/05/14 > I have devised a plan to pay off all my unsecured debts in less than 4 years.  This loan will help accomplish this goal and become debt free.<br>
# 384479                                                                                                                                                                                                                                                                                                                           NaN
# 1477940                                                                                                                                                                                                                                                                                                                          NaN
# 1159859                                                                                                                                                                                                                                                                                                                          NaN
# 875028                                                                                                                                                                                                                                                                                                                           NaN
# 1255627                                                                                                                                                                                                                                                                                                                          NaN
# 963952                                                                                                                                                                                                                                                                                                                           NaN
# 697652                                                                                                                                                                                                                                                                                                                           NaN
# 331272                                                                                                                                                                                                                                                                                                                           NaN
# 1144300                                                                                                                                                                                                                                                                                                                          NaN
# 1081105                                                                                                                                                                                                                                                                                                                          NaN
# 737831                                                                                                                                                                                                                                                                                                                           NaN
# 620501                                                                                                                                                                                                                                                                                                                           NaN
# 591366                                                                                                                                                                                                                                                                                                                           NaN
# 674340                                                                                                                                                                                                                                                                                                                           NaN
# 1229860                                                                                                                                                                                                                                                                                                                          NaN
# 77196                                                                                                                                                                                                                                                                                                                            NaN
# 1316669                                                                                                                                                                                                                                                                                                                          NaN
# 932642                                   Borrower added on 01/19/13 > This loan will pay off all lines of credit except for car and house mortgage.<br><br> Borrower added on 01/20/13 > My goal is too only have only one major bill at the end of the three years. My mortgage. I pay my bills so please help me with my goal.<br>
# 608512                                                                                                                                                                                                                                                                                                                           NaN
# 927721     Borrower added on 02/04/13 > I'm working on stabilizing my financial future and making all efforts to payoff credit card debt. Obtaining this loan will will be the next step in reaching my 5 year goal.  I have the willingness and capability to repay the debt and it will help to secure my financial future. :)<br>
# 956345                                                                                                                                                                                                                              Borrower added on 09/30/12 > To pay off credit cards and get my finanical life back on track<br>
# 969697                        Borrower added on 07/15/12 > Very happy to learn about Lending Club. Have some credit card usage (bad debt) that was incurred over the last few years. Have been diligent about paying it down but like the idea of having a fixed term loan and not paying interest to the credit card companies.<br>
# 315932                                                                                                                                                                                                                                                                                                                           NaN
# 1016862                                                                                                                                                                                                                                                                                                                          NaN
# 413166                                                                                                                                                                                                                                                                                                                           NaN
# 306670                                                                                                                                                                                                                                                                                                                           NaN
# 1565306                                                                                                                                                                                                                                                                                                                          NaN
# 850313                                                                                                                                                                   Borrower added on 09/17/13 > Paying off 3 credit cards to free up some montly cash. Left over funds will be used to partial pay my care credit account.<br>
# 287253                                                                                                                                                                                                                                                                                                                           NaN
# 224054                                                                                                                                                                                                                                                                                                                           NaN
# 209311                                                                                                                                                                                                                                                                                                                           NaN
# 1326918                                                                                                                                                                                                                                                                                                                          NaN
# 649108                                                                                                                                                                                                                                                                                                                           NaN
# 1288649                                                                                                                                                                                                                                                                                                                          NaN
# 1181953                                                                                                                                                                                                                                                                                                                          NaN
# 412849                                                                                                                                                                                                                                                                                                                           NaN
# 513939                                                                                                                                                                                                                                                                                                                           NaN
# 583777                                                                                                                                                                                                                                                                                                                           NaN
# 1270565                                                                                                                                                                                                                                                                                                                          NaN
# 1017861                                                                                                                                                                                                                                                                                                                          NaN
# 396552                                                                                                                                                                                                                                                                                                                           NaN
# ...
# 1181953                Cash                    N                       NaN
# 412849                 Cash                    N                       NaN
# 513939                 Cash                    N                       NaN
# 583777                 Cash                    N                       NaN
# 1270565                Cash                    N                       NaN
# 1017861                Cash                    N                       NaN
# 396552                 Cash                    N                       NaN
# 1111930                Cash                    N                       NaN
# 181149                 Cash                    N                       NaN
# 1644244                Cash                    N                       NaN
# 1478498                Cash                    N                       NaN
# 436674                 Cash                    N                       NaN
# 1221448                Cash                    N                       NaN
# 856049                 Cash                    N                       NaN
# 908350                 Cash                    N                       NaN
# 598920                 Cash                    N                       NaN
# 1065766                Cash                    N                       NaN
# 224479                 Cash                    N                       NaN
# 600328                 Cash                    N                       NaN
# 160555                 Cash                    N                       NaN
# 1120716                Cash                    N                       NaN
# 970405                 Cash                    N                       NaN
# 919740                 Cash                    N                       NaN
# 1023235                Cash                    N                       NaN
# 655697                 Cash                    N                       NaN
# 233573                 Cash                    N                       NaN
# 493308                 Cash                    N                       NaN
# 1057789                Cash                    N                       NaN
# 53152                  Cash                    N                       NaN
# 1089734                Cash                    N                       NaN
# 389463                 Cash                    N                       NaN
# 911667                 Cash                    N                       NaN
# 905580                 Cash                    N                       NaN
# 439916                 Cash                    N                       NaN
# 910414                 Cash                    N                       NaN
# 1603547                Cash                    N                       NaN
# 1254386                Cash                    N                       NaN
# 319837                 Cash                    N                       NaN
# 1307508                Cash                    N                       NaN
# 815008                 Cash                    N                       NaN
# 605759                 Cash                    N                       NaN
# 1504746                Cash                    N                       NaN
# 991107                 Cash                    N                       NaN
# 1008060                Cash                    N                       NaN
# 795618                 Cash                    N                       NaN
# 416714                 Cash                    N                       NaN
# 1566005                Cash                    N                       NaN
# 12375                  Cash                    N                       NaN
# 718577                 Cash                    N                       NaN
# 534296                 Cash                    N                       NaN
# 645027                 Cash                    N                       NaN
# 381104                 Cash                    N                       NaN
# 1486114                Cash                    N                       NaN
# 90133                  Cash                    N                       NaN
# 583490                 Cash                    N                       NaN
# 1267449                Cash                    N                       NaN
# 1292967                Cash                    N                       NaN
#
#         settlement_status settlement_date  settlement_amount  \
# 825766                NaN             NaN                NaN
# 820796                NaN             NaN                NaN
# 1058315               NaN             NaN                NaN
# 370430                NaN             NaN                NaN
# 290301                NaN             NaN                NaN
# 59514                 NaN             NaN                NaN
# 1632184               NaN             NaN                NaN
# 649679                NaN             NaN                NaN
# 232195                NaN             NaN                NaN
# 384479                NaN             NaN                NaN
# 1477940               NaN             NaN                NaN
# 1159859               NaN             NaN                NaN
# 875028                NaN             NaN                NaN
# 1255627               NaN             NaN                NaN
# 963952                NaN             NaN                NaN
# 697652                NaN             NaN                NaN
# 331272                NaN             NaN                NaN
# 1144300               NaN             NaN                NaN
# 1081105               NaN             NaN                NaN
# 737831                NaN             NaN                NaN
# 620501                NaN             NaN                NaN
# 591366                NaN             NaN                NaN
# 674340                NaN             NaN                NaN
# 1229860               NaN             NaN                NaN
# 77196                 NaN             NaN                NaN
# 1316669               NaN             NaN                NaN
# 932642                NaN             NaN                NaN
# 608512                NaN             NaN                NaN
# 927721                NaN             NaN                NaN
# 956345                NaN             NaN                NaN
# 969697                NaN             NaN                NaN
# 315932                NaN             NaN                NaN
# 1016862               NaN             NaN                NaN
# 413166                NaN             NaN                NaN
# 306670                NaN             NaN                NaN
# 1565306               NaN             NaN                NaN
# 850313                NaN             NaN                NaN
# 287253                NaN             NaN                NaN
# 224054                NaN             NaN                NaN
# 209311                NaN             NaN                NaN
# 1326918               NaN             NaN                NaN
# 649108                NaN             NaN                NaN
# 1288649               NaN             NaN                NaN
# 1181953               NaN             NaN                NaN
# 412849                NaN             NaN                NaN
# 513939                NaN             NaN                NaN
# 583777                NaN             NaN                NaN
# 1270565               NaN             NaN                NaN
# 1017861               NaN             NaN                NaN
# 396552                NaN             NaN                NaN
# 1111930               NaN             NaN                NaN
# 181149                NaN             NaN                NaN
# 1644244               NaN             NaN                NaN
# 1478498               NaN             NaN                NaN
# 436674                NaN             NaN                NaN
# 1221448               NaN             NaN                NaN
# 856049                NaN             NaN                NaN
# 908350                NaN             NaN                NaN
# 598920                NaN             NaN                NaN
# 1065766               NaN             NaN                NaN
# 224479                NaN             NaN                NaN
# 600328                NaN             NaN                NaN
# 160555                NaN             NaN                NaN
# 1120716               NaN             NaN                NaN
# 970405                NaN             NaN                NaN
# 919740                NaN             NaN                NaN
# 1023235               NaN             NaN                NaN
# 655697                NaN             NaN                NaN
# 233573                NaN             NaN                NaN
# 493308                NaN             NaN                NaN
# 1057789               NaN             NaN                NaN
# 53152                 NaN             NaN                NaN
# 1089734               NaN             NaN                NaN
# 389463                NaN             NaN                NaN
# 911667                NaN             NaN                NaN
# 905580                NaN             NaN                NaN
# 439916                NaN             NaN                NaN
# 910414                NaN             NaN                NaN
# 1603547               NaN             NaN                NaN
# 1254386               NaN             NaN                NaN
# 319837                NaN             NaN                NaN
# 1307508               NaN             NaN                NaN
# 815008                NaN             NaN                NaN
# 605759                NaN             NaN                NaN
# 1504746               NaN             NaN                NaN
# 991107                NaN             NaN                NaN
# 1008060               NaN             NaN                NaN
# 795618                NaN             NaN                NaN
# 416714                NaN             NaN                NaN
# 1566005               NaN             NaN                NaN
# 12375                 NaN             NaN                NaN
# 718577                NaN             NaN                NaN
# 534296                NaN             NaN                NaN
# 645027                NaN             NaN                NaN
# 381104                NaN             NaN                NaN
# 1486114               NaN             NaN                NaN
# 90133                 NaN             NaN                NaN
# 583490                NaN             NaN                NaN
# 1267449               NaN             NaN                NaN
# 1292967               NaN             NaN                NaN
#
#          settlement_percentage  settlement_term
# 825766                     NaN              NaN
# 820796                     NaN              NaN
# 1058315                    NaN              NaN
# 370430                     NaN              NaN
# 290301                     NaN              NaN
# 59514                      NaN              NaN
# 1632184                    NaN              NaN
# 649679                     NaN              NaN
# 232195                     NaN              NaN
# 384479                     NaN              NaN
# 1477940                    NaN              NaN
# 1159859                    NaN              NaN
# 875028                     NaN              NaN
# 1255627                    NaN              NaN
# 963952                     NaN              NaN
# 697652                     NaN              NaN
# 331272                     NaN              NaN
# 1144300                    NaN              NaN
# 1081105                    NaN              NaN
# 737831                     NaN              NaN
# 620501                     NaN              NaN
# 591366                     NaN              NaN
# 674340                     NaN              NaN
# 1229860                    NaN              NaN
# 77196                      NaN              NaN
# 1316669                    NaN              NaN
# 932642                     NaN              NaN
# 608512                     NaN              NaN
# 927721                     NaN              NaN
# 956345                     NaN              NaN
# 969697                     NaN              NaN
# 315932                     NaN              NaN
# 1016862                    NaN              NaN
# 413166                     NaN              NaN
# 306670                     NaN              NaN
# 1565306                    NaN              NaN
# 850313                     NaN              NaN
# 287253                     NaN              NaN
# 224054                     NaN              NaN
# 209311                     NaN              NaN
# 1326918                    NaN              NaN
# 649108                     NaN              NaN
# 1288649                    NaN              NaN
# 1181953                    NaN              NaN
# 412849                     NaN              NaN
# 513939                     NaN              NaN
# 583777                     NaN              NaN
# 1270565                    NaN              NaN
# 1017861                    NaN              NaN
# 396552                     NaN              NaN
# 1111930                    NaN              NaN
# 181149                     NaN              NaN
# 1644244                    NaN              NaN
# 1478498                    NaN              NaN
# 436674                     NaN              NaN
# 1221448                    NaN              NaN
# 856049                     NaN              NaN
# 908350                     NaN              NaN
# 598920                     NaN              NaN
# 1065766                    NaN              NaN
# 224479                     NaN              NaN
# 600328                     NaN              NaN
# 160555                     NaN              NaN
# 1120716                    NaN              NaN
# 970405                     NaN              NaN
# 919740                     NaN              NaN
# 1023235                    NaN              NaN
# 655697                     NaN              NaN
# 233573                     NaN              NaN
# 493308                     NaN              NaN
# 1057789                    NaN              NaN
# 53152                      NaN              NaN
# 1089734                    NaN              NaN
# 389463                     NaN              NaN
# 911667                     NaN              NaN
# 905580                     NaN              NaN
# 439916                     NaN              NaN
# 910414                     NaN              NaN
# 1603547                    NaN              NaN
# 1254386                    NaN              NaN
# 319837                     NaN              NaN
# 1307508                    NaN              NaN
# 815008                     NaN              NaN
# 605759                     NaN              NaN
# 1504746                    NaN              NaN
# 991107                     NaN              NaN
# 1008060                    NaN              NaN
# 795618                     NaN              NaN
# 416714                     NaN              NaN
# 1566005                    NaN              NaN
# 12375                      NaN              NaN
# 718577                     NaN              NaN
# 534296                     NaN              NaN
# 645027                     NaN              NaN
# 381104                     NaN              NaN
# 1486114                    NaN              NaN
# 90133                      NaN              NaN
# 583490                     NaN              NaN
# 1267449                    NaN              NaN
# 1292967                    NaN              NaN

# %% [markdown]
# # Train/Test Split

# %% [markdown]
# We'll try to make our predictions more realistic by performing the train/test split on the date of the loan. That is, we'll use loans from earlier dates to predict the status of loans on future dates.
#
# We'll use the variable `issue_d` (the month which the loan was funded) to organize the loans by year.

# %%
loans['issue_d'] = pd.to_datetime(loans['issue_d'])
loans['issue_yr'] = loans['issue_d'].dt.year

# %%
loans['issue_yr'].value_counts(normalize=True).sort_index()
# Out:
# 2007.0    0.000366
# 2008.0    0.001453
# 2009.0    0.003207
# 2010.0    0.007613
# 2011.0    0.013190
# 2012.0    0.032407
# 2013.0    0.081865
# 2014.0    0.143085
# 2015.0    0.255708
# 2016.0    0.263792
# 2017.0    0.197313
# Name: issue_yr, dtype: float64

# %% [markdown]
# # Response Variable
# <a id="3"></a>

# %% [markdown]
# We're going to try to predict the `loan_status` column. What are the value counts in this column?

# %%
loans['loan_status'].value_counts(dropna=False)

# %% [markdown]
# We're going to try to predict the final status of completed loans. More specifically, we'll only consider loans that meet the credit policy and have either been fully paid or charged off. These are the two cases we'll try to distinguish with a predictive model.
#
# So we only retain the rows with `loan_status` "Fully Paid" or "Charged Off." The other loans either (i) have not been completed, with status "Current," "Late," or "In Grace Period"; (ii) do not meet the credit policy; or (iii) have defaulted, a case that we won't consider because these loans are extremely rare.

# %%
loans = loans.loc[loans['loan_status'].isin(['Fully Paid', 'Charged Off'])]

# %% [markdown]
# How many observations remain?

# %%
loans.shape

# %% [markdown]
# Check we have the correct loans:

# %%
loans['loan_status'].value_counts(normalize=True, dropna=False) # Value counts as fractions of the total

# %% [markdown]
# About 79% of the remaining loans have been fully paid and 21% have been charged off, leading to a somewhat unbalanced classification problem. Let's convert the `loan_status` column to a binary `charged_off` column.

# %%
loans['loan_status'] = (loans['loan_status'] == 'Charged Off')

# %%
loans['loan_status'].value_counts(normalize=True, dropna=False)

# %% [markdown]
# Rename the `loan_status` column to `charged_off`.

# %%
loans.rename(columns={'loan_status':'charged_off'}, inplace=True)

# %% [markdown]
# Our target variable is ready to go. We have two classes to try to predict.

# %% [markdown]
# # Feature Selection
# <a id="4"></a>

# %% [markdown]
# The dataset has 150 features, but we won't be using all the features to predict the loan status. We'll eliminate any features that meet any of the following criteria:
# 1. More than 30% of the data is missing
# 2. The feature was not available in the loan application
# 3. Non-categorical text data
#
# Definitions of the features are given in the Lending Club Data Dictionary [available here](https://www.lendingclub.com/info/download-data.action).

# %% [markdown]
# ## Remove Features Missing Too Much Data
# <a id="4.2"></a>

# %% [markdown]
# First we calculate the percentage of missing data for each feature:

# %%
missing_fraction = loans.isnull().mean().sort_values(ascending=False)

# %% [markdown]
# Print the completion of columns with missing data:

# %%
print(missing_fraction.loc[missing_fraction > 0])
# Out:
# member_id                                     1.000000
# orig_projected_additional_accrued_interest    0.997072
# payment_plan_start_date                       0.996491
# hardship_start_date                           0.996491
# hardship_type                                 0.996491
# hardship_reason                               0.996491
# hardship_status                               0.996491
# deferral_term                                 0.996491
# hardship_last_payment_amount                  0.996491
# hardship_payoff_balance_amount                0.996491
# hardship_loan_status                          0.996491
# hardship_dpd                                  0.996491
# hardship_length                               0.996491
# hardship_amount                               0.996491
# hardship_end_date                             0.996491
# sec_app_mths_since_last_major_derog           0.995421
# settlement_term                               0.991930
# settlement_percentage                         0.991930
# debt_settlement_flag_date                     0.991930
# settlement_status                             0.991930
# settlement_date                               0.991930
# settlement_amount                             0.991930
# sec_app_revol_util                            0.986922
# sec_app_mort_acc                              0.986747
# revol_bal_joint                               0.986747
# sec_app_fico_range_low                        0.986747
# sec_app_fico_range_high                       0.986747
# sec_app_earliest_cr_line                      0.986747
# sec_app_inq_last_6mths                        0.986747
# sec_app_open_act_il                           0.986747
# sec_app_open_acc                              0.986747
# sec_app_num_rev_accts                         0.986747
# sec_app_chargeoff_within_12_mths              0.986747
# sec_app_collections_12_mths_ex_med            0.986747
# dti_joint                                     0.979044
# verification_status_joint                     0.979042
# annual_inc_joint                              0.979042
# desc                                          0.923447
# mths_since_last_record                        0.831040
# mths_since_recent_bc_dlq                      0.758860
# mths_since_last_major_derog                   0.734741
# mths_since_recent_revol_delinq                0.658539
# il_util                                       0.588681
# mths_since_rcnt_il                            0.538739
# all_util                                      0.525993
# open_acc_6m                                   0.525961
# total_cu_tl                                   0.525961
# inq_last_12m                                  0.525961
# open_act_il                                   0.525960
# open_il_24m                                   0.525960
# total_bal_il                                  0.525960
# open_rv_12m                                   0.525960
# open_rv_24m                                   0.525960
# max_bal_bc                                    0.525960
# open_il_12m                                   0.525960
# inq_fi                                        0.525960
# mths_since_last_delinq                        0.496156
# next_pymnt_d                                  0.494904
# mths_since_recent_inq                         0.133199
# num_tl_120dpd_2m                              0.081638
# mo_sin_old_il_acct                            0.070648
# emp_title                                     0.062220
# emp_length                                    0.057822
# pct_tl_nvr_dlq                                0.042781
# avg_cur_bal                                   0.042700
# mo_sin_rcnt_rev_tl_op                         0.042689
# mo_sin_old_rev_tl_op                          0.042689
# num_rev_accts                                 0.042689
# tot_coll_amt                                  0.042688
# tot_cur_bal                                   0.042688
# num_accts_ever_120_pd                         0.042688
# num_tl_op_past_12m                            0.042688
# num_tl_90g_dpd_24m                            0.042688
# num_tl_30dpd                                  0.042688
# tot_hi_cred_lim                               0.042688
# num_rev_tl_bal_gt_0                           0.042688
# num_actv_bc_tl                                0.042688
# total_rev_hi_lim                              0.042688
# total_il_high_credit_limit                    0.042688
# num_actv_rev_tl                               0.042688
# mo_sin_rcnt_tl                                0.042688
# num_op_rev_tl                                 0.042688
# num_bc_tl                                     0.042688
# num_il_tl                                     0.042688
# bc_util                                       0.040902
# percent_bc_gt_75                              0.040635
# bc_open_to_buy                                0.040375
# mths_since_recent_bc                          0.039755
# num_bc_sats                                   0.035592
# num_sats                                      0.035592
# acc_open_past_24mths                          0.030394
# mort_acc                                      0.030394
# total_bal_ex_mort                             0.030394
# total_bc_limit                                0.030394
# title                                         0.014178
# last_pymnt_d                                  0.000996
# pub_rec_bankruptcies                          0.000843
# revol_util                                    0.000633
# dti                                           0.000231
# collections_12_mths_ex_med                    0.000102
# chargeoff_within_12_mths                      0.000102
# tax_liens                                     0.000078
# last_credit_pull_d                            0.000055
# inq_last_6mths                                0.000032
# delinq_2yrs                                   0.000032
# acc_now_delinq                                0.000032
# earliest_cr_line                              0.000032
# pub_rec                                       0.000032
# total_acc                                     0.000032
# delinq_amnt                                   0.000032
# open_acc                                      0.000032
# annual_inc                                    0.000016
# zip_code                                      0.000015
# loan_status                                   0.000014
# disbursement_method                           0.000014
# pymnt_plan                                    0.000014
# policy_code                                   0.000014
# issue_d                                       0.000014
# purpose                                       0.000014
# home_ownership                                0.000014
# sub_grade                                     0.000014
# grade                                         0.000014
# installment                                   0.000014
# int_rate                                      0.000014
# term                                          0.000014
# funded_amnt_inv                               0.000014
# funded_amnt                                   0.000014
# loan_amnt                                     0.000014
# debt_settlement_flag                          0.000014
# verification_status                           0.000014
# fico_range_low                                0.000014
# addr_state                                    0.000014
# total_rec_int                                 0.000014
# last_fico_range_low                           0.000014
# last_fico_range_high                          0.000014
# application_type                              0.000014
# last_pymnt_amnt                               0.000014
# collection_recovery_fee                       0.000014
# recoveries                                    0.000014
# total_rec_late_fee                            0.000014
# total_rec_prncp                               0.000014
# fico_range_high                               0.000014
# total_pymnt_inv                               0.000014
# total_pymnt                                   0.000014
# out_prncp_inv                                 0.000014
# out_prncp                                     0.000014
# initial_list_status                           0.000014
# revol_bal                                     0.000014
# hardship_flag                                 0.000014
# dtype: float64

# %% [markdown]
# How many columns have missing data?

# %%
len(fraction_not_null[fraction_not_null < 1])

# %% [markdown]
# Note there's a large gap between features missing "some" data and those missing "lots" of data:
#
# Because it's generally very difficult to accurately impute data with more than 30% missing values, we drop these columns. Find the features to drop:

# %%
drop_list = fraction_not_null[fraction_not_null < 0.7].index
print(drop_list)

# %%
len(drop_list)

# %% [markdown]
# Now drop these 58 features.

# %%
loans.shape

# %%
loans.drop(labels=drop_list, axis=1, inplace=True)

# %%
loans.shape

# %%
fraction_not_null.drop(labels=drop_list, inplace=True)

# %% [markdown]
# ## Remove irrelevant features
# <a id="4.3"></a>

# %% [markdown]
# Let's drop some features that we don't think will be useful for predicting the loan status:

# %%
df.shape

# %%
df.drop(labels=['id', 'emp_title', 'title', 'issue_d', 'last_credit_pull_d', 'earliest_cr_line'], axis=1, inplace=True)

# %%
df.shape

# %% [markdown]
# ## Remove features that could make predictions too easy
# <a id="4.4"></a>

# %% [markdown]
# Some features might perfectly predict the loan status. For example, if `debt_settlement_flag` is 'Y', this implies that the borrower charged off. Also, if `total_pymnt` is greater than `loan_amnt`, and similarly for interest and fee payment features, then the loan must be paid off. Let's remove these columns so that predicting charge-offs isn't trivially simple.

# %%
df.shape

# %%
df.drop(labels=['collection_recovery_fee', 'debt_settlement_flag', 'last_pymnt_amnt', 'last_pymnt_d', 'recoveries', 'total_pymnt', 'total_pymnt_inv', 'total_rec_int', 'total_rec_late_fee', 'total_rec_prncp'], axis=1, inplace=True)

# %%
df.shape

# %% [markdown]
# ## Inspect non-numerical features
# <a id="4.5"></a>

# %% [markdown]
# We're going to inspect features of type `object`, i.e. text data.

# %%
df.sample(3)

# %% [markdown]
# Which columns have text data?

# %%
text_cols = []
for col in df.columns:
    if df[col].dtype == np.object:
        text_cols.append(col)

text_cols

# %% [markdown]
# ### term

# %%
df['term'].value_counts(dropna=False)

# %% [markdown]
# Convert `term` to integer values.

# %%
df['term'] = df['term'].apply(lambda s:np.int8(s[1:3])) # There's an extra space in the data for some reason

# %%
df['term'].value_counts()

# %% [markdown]
# ### grade, sub_grade

# %%
df['grade'].value_counts().sort_index()

# %% [markdown]
# The grade is implied by the subgrade, so let's drop the grade column.

# %%
df.drop(labels=['grade'], axis=1, inplace=True)

# %% [markdown]
# ### emp_length

# %%
df['emp_length'].value_counts(dropna=False).sort_index()

# %% [markdown]
# Let's convert `emp_length` to floats:

# %%
def emp_conv(s):
    try:
        if pd.isnull(s):
            return s
        elif s[0] == '<':
            return 0.0
        elif s[:2] == '10':
            return 10.0
        else:
            return float(s[0])
    except TypeError:
        return float(s)

# %%
df['emp_length'] = df['emp_length'].apply(lambda s: emp_conv(s))

# %%
df['emp_length'].value_counts(dropna=False).sort_index()

# %% [markdown]
# ### home_ownership

# %%
df['home_ownership'].value_counts()

# %% [markdown]
# ### verification_status

# %%
df['verification_status'].value_counts()

# %% [markdown]
# ### pymnt_plan

# %%
df['pymnt_plan'].value_counts(dropna=False)

# %% [markdown]
# This feature will be removed automatically later.

# %% [markdown]
# ### purpose

# %%
df['purpose'].value_counts()

# %% [markdown]
# ### zip_code, addr_state

# %%
df['zip_code'].nunique()

# %%
df['addr_state'].nunique()

# %% [markdown]
# There are a lot of zip codes, so let's just retain the state column.

# %%
df.drop(labels=['zip_code'], axis=1, inplace=True)

# %% [markdown]
# ### initial_list_status

# %%
df['initial_list_status'].value_counts()

# %% [markdown]
# I wasn't able to determine what the initial list status means.

# %% [markdown]
# ### application_type

# %%
df['application_type'].value_counts()

# %% [markdown]
# ### hardship_flag

# %%
df['hardship_flag'].value_counts()

# %% [markdown]
# This feature will be removed automatically later.

# %% [markdown]
# ### disbursement_method

# %%
df['disbursement_method'].value_counts()

# %% [markdown]
# # Exploratory Data Analysis
# <a id="5"></a>

# %% [markdown]
# View some random rows:

# %%
df.sample(3)

# %% [markdown]
# Let's make a count plot of the loan purpose, separated by the `charged_off` value.

# %%
plt.figure(figsize=(12,6), dpi=100)
sns.countplot(y='purpose', hue='charged_off', data=df, orient='h')

# %% [markdown]
# It appears that most of the charge-offs come from loans for debt consolidation or to pay off credit cards.

# %% [markdown]
# Let's make a similar plot, but with `sub_grade` instead of `purpose`.

# %%
plt.figure(figsize=(16,6), dpi=120)
sns.countplot(x='sub_grade', hue='charged_off', data=df, order=sorted(df['sub_grade'].value_counts().index))

# %% [markdown]
# There's a clear trend of higher probability of charge-off as the subgrade worsens.

# %% [markdown]
# Let's make yet another similar plot, but with `term` instead of `sub_grade`.

# %%
plt.figure(figsize=(4,4), dpi=90)
sns.countplot(x='term', hue='charged_off', data=df)

# %% [markdown]
# Loans with a term of 60 months are much more likely to be charged off.

# %% [markdown]
# Now let's compare the interest rate to the loan status using histograms:

# %%
plt.figure(figsize=(10,4), dpi=90)
sns.distplot(df['int_rate'].loc[df['charged_off']==0], kde=True, label='charged_off = 0')
sns.distplot(df['int_rate'].loc[df['charged_off']==1], kde=True, label='charged_off = 1')
plt.xlabel('int_rate')
plt.ylabel('density')
plt.legend()

# %% [markdown]
# Charged-off loans tend to have higher interest rates.

# %% [markdown]
# Now let's compare the borrower's most recent FICO score (a credit score) to the loan status.

# %%
plt.figure(figsize=(10,4), dpi=90)
sns.distplot(df['last_fico_range_high'].loc[df['charged_off']==0], label='charged_off = 0')
sns.distplot(df['last_fico_range_high'].loc[df['charged_off']==1], label='charged_off = 1')
plt.xlabel('last_fico_range_high')
plt.ylabel('density')
plt.legend()

# %% [markdown]
# There's a strong correlation here: charged-off loans tend to have much lower FICO scores.

# %% [markdown]
# # More Pre-processing
# <a id="7"></a>

# %% [markdown]
# ## Create dummy variables
# <a id="6.1"></a>

# %%
df.shape

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.shape

# %% [markdown]
# Now all the features (171 of them) are numerical. What does the data look like after converting categorical features to dummy variables?

# %%
df.sample(3)

# %% [markdown]
# ## Train/test split
# <a id="7.1"></a>

# %%
X = df.drop(labels=['charged_off'], axis=1) # Features
y = df.loc[:,'charged_off'] # Response variable
df = None

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Let's do a 90/10 train/test split.

# %%
random_state = 1 # Just to make the results fixed
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=random_state, stratify=y)
X = None
y = None

# %%
X_train.shape

# %%
X_test.shape

# %% [markdown]
# ## Imputation with mean substitution
# <a id="7.2"></a>

# %% [markdown]
# How complete is our training data?

# %%
incomplete_cols(X_train)

# %% [markdown]
# The learning algorithms cannot have missing data. Perform mean substitution, using only the means of the training set to prevent test set leakage.

# %%
from sklearn.preprocessing import Imputer

# %%
imputer = Imputer().fit(X_train)

# %%
X_train = pd.DataFrame(imputer.transform(X_train), columns=X_train.columns)
X_test  = pd.DataFrame(imputer.transform(X_test),  columns=X_test.columns)

# %% [markdown]
# ## Standardize the data
# <a id="7.3"></a>

# %% [markdown]
# Shift and scale each column individually so that it has zero mean and unit variance. This will help to train the linear models.
#
# Train the scaler using only the training data to prevent test set leakage.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler().fit(X_train)

# %%
X_train = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
X_test  = pd.DataFrame(scaler.transform(X_test),  columns=X_test.columns)

# %% [markdown]
# ## Automatic feature selection

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif

# %%
selector = SelectKBest(mutual_info_classif, k=15)

# %%
selector.fit(X_train.iloc[1:50000], y_train.iloc[1:50000])

# %%
X_train.shape

# %%
X_test.shape

# %%
X_train = selector.transform(X_train)
X_test  = selector.transform(X_test)

# %%
X_train.shape

# %%
X_test.shape

# %% [markdown]
# # Predictive Modeling: SGDClassifier
# <a id="8"></a>

# %% [markdown]
# I decided to use a SGD Classifier by looking at the machine learning flowchart here: http://scikit-learn.org/stable/tutorial/machine_learning_map/index.html.
#
# The SGDClassifier estimator implements linear classifiers (SVM, logistic regression, a.o.) with SGD training. The linear classifier is chosen by the `loss` hyperparameter.

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import matthews_corrcoef, make_scorer

# %% [markdown]
# ## Train with grid search
# <a id="8.1"></a>

# %% [markdown]
# We're going to search through many hyperparameters of SGDClassifier using an exhaustive grid search with 3-fold cross-validation, implemented in GridSearchCV.
#
# Here are the hyperparameters that we'll try:

# %%
param_grid = [{'loss': ['hinge'],
               'alpha': [10.0**k for k in range(-3, 3)],
               'class_weight': [None, 'balanced']},
              {'loss': ['log'],
               'alpha': [10.0**k for k in range(-3, 3)],
               'penalty': ['l2', 'l1']}]

# %% [markdown]
# Instantiate the grid estimator. We'll use the Matthews correlation coefficient as our scoring metric.

# %%
grid = GridSearchCV(estimator=SGDClassifier(max_iter=1000, tol=1e-3, random_state=random_state, warm_start=True), param_grid=param_grid, scoring=make_scorer(matthews_corrcoef), n_jobs=4, pre_dispatch=8, cv=5, verbose=1)

# %% [markdown]
# Run the grid search (this could take some time).

# %%
grid.fit(X_train, y_train)

# %% [markdown]
# Hyperparameters that gave the best results on the hold out data:

# %%
grid.best_params_

# %% [markdown]
# Mean cross-validated MCC score of the best estimator:

# %%
grid.best_score_

# %% [markdown]
# Weights assigned to the features by the best estimator:

# %%
plt.figure(figsize=(6,4), dpi=90)
sns.barplot(y=np.arange(0,15), x=grid.best_estimator_.coef_[0,:], orient='h')
plt.title("Classifier Weights")
plt.xlabel("classifier weight")

# %% [markdown]
# ## Test set evaluation
# <a id="8.2"></a>

# %%
from sklearn.metrics import confusion_matrix, classification_report, matthews_corrcoef, cohen_kappa_score, accuracy_score, average_precision_score, roc_auc_score

# %%
def classification_eval(estimator, X_test, y_test):
    """
    Print several metrics of classification performance of an estimator, given features X_test and true labels y_test.
    
    Input: estimator or GridSearchCV instance, X_test, y_test
    Returns: text printout of metrics
    """
    y_pred = estimator.predict(X_test)
    
    # Number of decimal places based on number of samples
    dec = np.int64(np.ceil(np.log10(len(y_test))))
    
    print('Confusion matrix')
    print(confusion_matrix(y_test, y_pred), '\n')
    
    print('Classification report')
    print(classification_report(y_test, y_pred, digits=dec))
    
    print('Scalar metrics')
    format_str = '%%13s = %%.%if' % dec
    print(format_str % ('MCC', matthews_corrcoef(y_test, y_pred)))
    if y_test.nunique() <= 2: # Additional metrics for binary classification
        try:
            y_score = estimator.predict_proba(X_test)[:,1]
        except:
            y_score = estimator.decision_function(X_test)
        print(format_str % ('AUPRC', average_precision_score(y_test, y_score)))
        print(format_str % ('AUROCC', roc_auc_score(y_test, y_score)))
    print(format_str % ("Cohen's kappa", cohen_kappa_score(y_test, y_pred)))
    print(format_str % ('Accuracy', accuracy_score(y_test, y_pred)))
    # Add Informedness
    # Add Markedness
    # Add Fleiss' kappa

# %% [markdown]
# Test set evaluation metrics:

# %%
classification_eval(grid, X_test, y_test)
