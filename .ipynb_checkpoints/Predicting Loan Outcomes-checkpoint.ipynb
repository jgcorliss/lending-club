# %% [markdown]
# # Predicting Loan Charge-offs on Lending Club
#
# ***By Joe Corliss***
#
# **May 28, 2018**

# %% [markdown]
# ## Table of Contents
#
# 1. [Summary](#1)
#     1. [Spoilers](#1.1)

# %% [markdown]
# # Introduction

# %% [markdown]
# [Dataset 1](https://www.kaggle.com/wordsforthewise/lending-club) - The dataset used in this project, hosted on Kaggle
#
# [Dataset 2](https://www.kaggle.com/wendykan/lending-club-loan-data) - Another Lending Club dataset on Kaggle, not used in this project
#
# [Kaggle notebook](https://www.kaggle.com/pileatedperch/predicting-loan-status-mcc-0-73) - This notebook on Kaggle
#
# [Lending Club statistics](https://www.lendingclub.com/info/download-data.action) - Original data source
#
# [GitHub repository](https://github.com/jgcorliss/lending-club) - This project on GitHub
#
# [EXPAND INTRODUCTION] The goal of this project is to predict loan charge-offs only using data available at the time of the loan application.

# %% [markdown]
# # Import the Data
# <a id="2"></a>

# %% [markdown]
# Package imports:

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Pandas options
pd.set_option('display.max_colwidth', 1000, 'display.max_rows', None, 'display.max_columns', None)

# Plotting options
# %matplotlib inline
mpl.style.use('ggplot')
sns.set(style='whitegrid')

# %% [markdown]
# Read the data into a pandas dataframe.

# %%
loans = pd.read_csv('accepted_2007_to_2017Q3.csv.gz', compression='gzip')
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (0,18,48,58,117,128,129,130,133,134,135,138,144,145,146) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Check basic dataframe info.

# %%
loans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1646801 entries, 0 to 1646800
# Columns: 150 entries, id to settlement_term
# dtypes: float64(113), object(37)
# memory usage: 1.8+ GB

# %% [markdown]
# Let's view the data from some randomly chosen loans:

# %%
loans.sample(5)
# Out:
#                id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 722630  108517390        NaN    40000.0      40000.0          40000.0
# 169598   14218338        NaN    14400.0      14400.0          14400.0
# 225918   10598574        NaN    20000.0      20000.0          19950.0
# 66672    26599285        NaN    16300.0      16300.0          16300.0
# 439363   58653946        NaN    10875.0      10875.0          10875.0
#
#               term  int_rate  installment grade sub_grade  \
# 722630   36 months     10.91      1307.85     B        B4
# 169598   60 months     15.61       347.21     C        C5
# 225918   60 months     14.47       470.26     C        C2
# 66672    36 months     17.57       585.78     D        D4
# 439363   36 months     18.25       394.53     E        E1
#
#                               emp_title emp_length home_ownership  annual_inc  \
# 722630  Emergency department physician   10+ years       MORTGAGE    600000.0
# 169598                      LoanOfficer    3 years       MORTGAGE     94000.0
# 225918         Aviation Insurace Claims    3 years       MORTGAGE    103000.0
# 66672        Personal Lines Underwriter    7 years            OWN     45000.0
# 439363                          Courier     1 year           RENT     32000.0
#
#        verification_status   issue_d loan_status pymnt_plan desc  \
# 722630            Verified  Jun-2017     Current          n  NaN
# 169598        Not Verified  Apr-2014  Fully Paid          n  NaN
# 225918            Verified  Jan-2014     Current          n  NaN
# 66672      Source Verified  Oct-2014  Fully Paid          n  NaN
# 439363            Verified  Aug-2015  Fully Paid          n  NaN
#
#                    purpose               title zip_code addr_state    dti  \
# 722630  debt_consolidation  Debt consolidation    295xx         SC   4.83
# 169598               other               Other    088xx         NJ   5.69
# 225918      major_purchase      Major purchase    086xx         NJ  22.66
# 66672   debt_consolidation  Debt consolidation    112xx         NY  32.30
# 439363      major_purchase      Major purchase    766xx         TX   7.31
#
#         delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 722630          1.0         Jul-1991           730.0            734.0
# 169598          0.0         Mar-2004           675.0            679.0
# 225918          0.0         May-2003           715.0            719.0
# 66672           0.0         Sep-2006           685.0            689.0
# 439363          0.0         Dec-2008           680.0            684.0
#
#         inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 722630             0.0                    18.0                    25.0
# 169598             2.0                    34.0                     NaN
# 225918             0.0                    62.0                     NaN
# 66672              0.0                     NaN                     NaN
# 439363             0.0                    41.0                     NaN
#
#         open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 722630      12.0      1.0    28381.0        57.2       21.0
# 169598       7.0      0.0     9882.0        48.2       22.0
# 225918      14.0      0.0    40605.0        68.5       27.0
# 66672       23.0      0.0    31824.0        55.6       26.0
# 439363       3.0      0.0      622.0        14.5       30.0
#
#        initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 722630                   w   34207.82       34207.82   7926.790000
# 169598                   f       0.00           0.00  17551.550000
# 225918                   f    6024.10        6009.04  21631.960000
# 66672                    w       0.00           0.00  21125.429427
# 439363                   f       0.00           0.00  13416.267254
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 722630          7926.79          5792.18        2134.61                 0.0
# 169598         17551.55         14400.00        3151.55                 0.0
# 225918         21577.88         13975.90        7656.06                 0.0
# 66672          21125.43         16300.00        4825.43                 0.0
# 439363         13416.27         10875.00        2541.27                 0.0
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 722630         0.0                      0.0     Dec-2017          1307.85
# 169598         0.0                      0.0     Oct-2015         11648.98
# 225918         0.0                      0.0     Dec-2017           470.26
# 66672          0.0                      0.0     Oct-2017           585.50
# 439363         0.0                      0.0     Mar-2017          6336.78
#
#        next_pymnt_d last_credit_pull_d  last_fico_range_high  \
# 722630     Jan-2018           Dec-2017                 739.0
# 169598          NaN           Feb-2017                 734.0
# 225918     Jan-2018           Dec-2017                 649.0
# 66672           NaN           Dec-2017                 699.0
# 439363          NaN           Aug-2017                 734.0
#
#         last_fico_range_low  collections_12_mths_ex_med  \
# 722630                735.0                         0.0
# 169598                730.0                         0.0
# 225918                645.0                         0.0
# 66672                 695.0                         0.0
# 439363                730.0                         0.0
#
#         mths_since_last_major_derog  policy_code application_type  \
# 722630                          NaN          1.0       Individual
# 169598                          NaN          1.0       Individual
# 225918                         62.0          1.0       Individual
# 66672                           NaN          1.0       Individual
# 439363                         41.0          1.0       Individual
#
#         annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 722630               NaN        NaN                       NaN             0.0
# 169598               NaN        NaN                       NaN             0.0
# 225918               NaN        NaN                       NaN             0.0
# 66672                NaN        NaN                       NaN             0.0
# 439363               NaN        NaN                       NaN             0.0
#
#         tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 722630           0.0     445769.0          0.0          3.0          0.0
# 169598           0.0     138898.0          NaN          NaN          NaN
# 225918           0.0     251068.0          NaN          NaN          NaN
# 66672            0.0      58273.0          NaN          NaN          NaN
# 439363           0.0      38021.0          NaN          NaN          NaN
#
#         open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 722630          0.0                41.0       10868.0      5.0          0.0
# 169598          NaN                 NaN           NaN      NaN          NaN
# 225918          NaN                 NaN           NaN      NaN          NaN
# 66672           NaN                 NaN           NaN      NaN          NaN
# 439363          NaN                 NaN           NaN      NaN          NaN
#
#         open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 722630          1.0     18508.0      45.0           49600.0     1.0
# 169598          NaN         NaN       NaN           20500.0     NaN
# 225918          NaN         NaN       NaN           59300.0     NaN
# 66672           NaN         NaN       NaN           57200.0     NaN
# 439363          NaN         NaN       NaN            4300.0     NaN
#
#         total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 722630          0.0           1.0                   1.0      37147.0
# 169598          NaN           NaN                   3.0      23150.0
# 225918          NaN           NaN                   3.0      17933.0
# 66672           NaN           NaN                   3.0       2649.0
# 439363          NaN           NaN                   5.0      12674.0
#
#         bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 722630          7342.0     79.4                       0.0          0.0
# 169598         10404.0     47.5                       0.0          0.0
# 225918          8597.0     70.3                       0.0          0.0
# 66672          25276.0     55.7                       0.0          0.0
# 439363             NaN      NaN                       0.0          0.0
#
#         mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 722630               161.0                 310.0                   14.0
# 169598               121.0                 108.0                    6.0
# 225918               103.0                 128.0                    7.0
# 66672                 22.0                  96.0                   34.0
# 439363                80.0                  61.0                    9.0
#
#         mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 722630            14.0       2.0                 137.0
# 169598             6.0       1.0                   6.0
# 225918             7.0       3.0                   7.0
# 66672              6.0       0.0                  34.0
# 439363             9.0       0.0                   NaN
#
#         mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 722630                      18.0                    3.0
# 169598                       NaN                    1.0
# 225918                       NaN                    NaN
# 66672                        NaN                   13.0
# 439363                       NaN                    9.0
#
#         mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 722630                            18.0                    0.0             3.0
# 169598                            34.0                    0.0             3.0
# 225918                             NaN                    1.0             8.0
# 66672                              NaN                    0.0            14.0
# 439363                            41.0                    0.0             0.0
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 722630              4.0          4.0        7.0        8.0            8.0
# 169598              4.0          4.0       12.0        5.0            5.0
# 225918             11.0          8.0       12.0        4.0           11.0
# 66672              14.0         17.0       19.0        3.0           19.0
# 439363              2.0          0.0        0.0       27.0            2.0
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 722630           11.0                  4.0      12.0               0.0
# 169598           16.0                  4.0       7.0               0.0
# 225918           19.0                 11.0      14.0               0.0
# 66672            22.0                 14.0      23.0               0.0
# 439363            3.0                  2.0       3.0               0.0
#
#         num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 722630           0.0                 0.0                 0.0            76.2
# 169598           0.0                 0.0                 2.0            95.2
# 225918           0.0                 0.0                 3.0            96.3
# 66672            0.0                 0.0                 1.0           100.0
# 439363           0.0                 0.0                 1.0            96.6
#
#         percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 722630              50.0                   0.0        1.0        1075286.0
# 169598              33.3                   0.0        0.0         153345.0
# 225918              50.0                   0.0        0.0         311270.0
# 66672               47.1                   0.0        0.0          88060.0
# 439363               NaN                   0.0        0.0          41699.0
#
#         total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 722630            39249.0         35700.0                    100686.0
# 169598            22709.0         19800.0                     15995.0
# 225918            66373.0         28900.0                     39970.0
# 66672             58273.0         57100.0                     22945.0
# 439363            38021.0             0.0                     37399.0
#
#         revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 722630              NaN                     NaN                      NaN
# 169598              NaN                     NaN                      NaN
# 225918              NaN                     NaN                      NaN
# 66672               NaN                     NaN                      NaN
# 439363              NaN                     NaN                      NaN
#
#        sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 722630                      NaN                     NaN               NaN
# 169598                      NaN                     NaN               NaN
# 225918                      NaN                     NaN               NaN
# 66672                       NaN                     NaN               NaN
# 439363                      NaN                     NaN               NaN
#
#         sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 722630               NaN                 NaN                  NaN
# 169598               NaN                 NaN                  NaN
# 225918               NaN                 NaN                  NaN
# 66672                NaN                 NaN                  NaN
# 439363               NaN                 NaN                  NaN
#
#         sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 722630                    NaN                               NaN
# 169598                    NaN                               NaN
# 225918                    NaN                               NaN
# 66672                     NaN                               NaN
# 439363                    NaN                               NaN
#
#         sec_app_collections_12_mths_ex_med  \
# 722630                                 NaN
# 169598                                 NaN
# 225918                                 NaN
# 66672                                  NaN
# 439363                                 NaN
#
#         sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 722630                                  NaN             N           NaN
# 169598                                  NaN             N           NaN
# 225918                                  NaN             N           NaN
# 66672                                   NaN             N           NaN
# 439363                                  NaN             N           NaN
#
#        hardship_reason hardship_status  deferral_term  hardship_amount  \
# 722630             NaN             NaN            NaN              NaN
# 169598             NaN             NaN            NaN              NaN
# 225918             NaN             NaN            NaN              NaN
# 66672              NaN             NaN            NaN              NaN
# 439363             NaN             NaN            NaN              NaN
#
#        hardship_start_date hardship_end_date payment_plan_start_date  \
# 722630                 NaN               NaN                     NaN
# 169598                 NaN               NaN                     NaN
# 225918                 NaN               NaN                     NaN
# 66672                  NaN               NaN                     NaN
# 439363                 NaN               NaN                     NaN
#
#         hardship_length  hardship_dpd hardship_loan_status  \
# 722630              NaN           NaN                  NaN
# 169598              NaN           NaN                  NaN
# 225918              NaN           NaN                  NaN
# 66672               NaN           NaN                  NaN
# 439363              NaN           NaN                  NaN
#
#         orig_projected_additional_accrued_interest  \
# 722630                                         NaN
# 169598                                         NaN
# 225918                                         NaN
# 66672                                          NaN
# 439363                                         NaN
#
#         hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 722630                             NaN                           NaN
# 169598                             NaN                           NaN
# 225918                             NaN                           NaN
# 66672                              NaN                           NaN
# 439363                             NaN                           NaN
#
#        disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 722630                Cash                    N                       NaN
# 169598                Cash                    N                       NaN
# 225918                Cash                    N                       NaN
# 66672                 Cash                    N                       NaN
# 439363                Cash                    N                       NaN
#
#        settlement_status settlement_date  settlement_amount  \
# 722630               NaN             NaN                NaN
# 169598               NaN             NaN                NaN
# 225918               NaN             NaN                NaN
# 66672                NaN             NaN                NaN
# 439363               NaN             NaN                NaN
#
#         settlement_percentage  settlement_term
# 722630                    NaN              NaN
# 169598                    NaN              NaN
# 225918                    NaN              NaN
# 66672                     NaN              NaN
# 439363                    NaN              NaN

# %% [markdown]
# # Response Variable
# <a id="3"></a>

# %% [markdown]
# We're going to try to predict the `loan_status` column. What are the value counts in this column?

# %%
loans['loan_status'].value_counts(dropna=False)
# Out:
# Current                                                788950
# Fully Paid                                             646902
# Charged Off                                            168084
# Late (31-120 days)                                      23763
# In Grace Period                                         10474
# Late (16-30 days)                                        5786
# Does not meet the credit policy. Status:Fully Paid       1988
# Does not meet the credit policy. Status:Charged Off       761
# Default                                                    70
# NaN                                                        23
# Name: loan_status, dtype: int64

# %% [markdown]
# We're going to try to predict the final status of completed loans. More specifically, we'll only consider loans that meet the credit policy and have either been fully paid or charged off. These are the two cases we'll try to distinguish with a predictive model.
#
# So we only retain the loans with `loan_status` "Fully Paid" or "Charged Off." The other loans either (i) have not been completed, with status "Current," "Late," or "In Grace Period"; (ii) do not meet the credit policy; or (iii) have defaulted, a case that we won't consider because these loans are extremely rare.

# %%
loans = loans.loc[loans['loan_status'].isin(['Fully Paid', 'Charged Off'])]

# %% [markdown]
# How many loans remain in the dataset?

# %%
loans.shape
# Out:
# (814986, 150)

# %% [markdown]
# Check the status counts:

# %%
loans['loan_status'].value_counts(dropna=False)
# Out:
# Fully Paid     646902
# Charged Off    168084
# Name: loan_status, dtype: int64

# %% [markdown]
# Status counts as percentages:

# %%
loans['loan_status'].value_counts(normalize=True, dropna=False)
# Out:
# Fully Paid     0.793758
# Charged Off    0.206242
# Name: loan_status, dtype: float64

# %% [markdown]
# About 79% of the remaining loans have been fully paid and 21% have been charged off, leading to a somewhat unbalanced classification problem.

# %% [markdown]
# # Feature Selection
# <a id="4"></a>

# %% [markdown]
# The dataset has 150 features, but we won't be using all the features to predict the loan status. We'll first drop any features that meet either of the following criteria:
#
# 1. More than 30% of the data is missing (in the training set)
# 2. The feature would not have been available at the time of the loan application
#
# Definitions of the features are given in the Lending Club Data Dictionary [available here](https://www.lendingclub.com/info/download-data.action).

# %% [markdown]
# ## Drop features missing too much data
# <a id="4.2"></a>

# %% [markdown]
# First we calculate the percentage of missing data for each feature:

# %%
missing_fractions = loans.isnull().mean().sort_values(ascending=False)

# %% [markdown]
# Let's visualize the distribution of missing data percentages:

# %%
plt.figure(figsize=(6,3), dpi=90)
missing_fractions.plot.hist(bins=20)
plt.title('Histogram of Variable Incompleteness')
plt.xlabel('Fraction of data missing')
plt.ylabel('Variable count')
# Out:
# Text(0,0.5,'Variable count')

# %% [markdown]
# From the above histogram, we see there's a large gap between features missing "some" data and those missing "lots" of data. Because it's generally very difficult to accurately impute data with more than 30% missing values, we drop such columns. First store all variables missing more than 30% data in a list:

# %%
drop_list = sorted(list(missing_fractions[missing_fractions > 0.3].index))
print(drop_list)
# Out:
# ['all_util', 'annual_inc_joint', 'debt_settlement_flag_date', 'deferral_term', 'desc', 'dti_joint', 'hardship_amount', 'hardship_dpd', 'hardship_end_date', 'hardship_last_payment_amount', 'hardship_length', 'hardship_loan_status', 'hardship_payoff_balance_amount', 'hardship_reason', 'hardship_start_date', 'hardship_status', 'hardship_type', 'il_util', 'inq_fi', 'inq_last_12m', 'max_bal_bc', 'member_id', 'mths_since_last_delinq', 'mths_since_last_major_derog', 'mths_since_last_record', 'mths_since_rcnt_il', 'mths_since_recent_bc_dlq', 'mths_since_recent_revol_delinq', 'next_pymnt_d', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'open_rv_12m', 'open_rv_24m', 'orig_projected_additional_accrued_interest', 'payment_plan_start_date', 'revol_bal_joint', 'sec_app_chargeoff_within_12_mths', 'sec_app_collections_12_mths_ex_med', 'sec_app_earliest_cr_line', 'sec_app_fico_range_high', 'sec_app_fico_range_low', 'sec_app_inq_last_6mths', 'sec_app_mort_acc', 'sec_app_mths_since_last_major_derog', 'sec_app_num_rev_accts', 'sec_app_open_acc', 'sec_app_open_act_il', 'sec_app_revol_util', 'settlement_amount', 'settlement_date', 'settlement_percentage', 'settlement_status', 'settlement_term', 'total_bal_il', 'total_cu_tl', 'verification_status_joint']

# %% [markdown]
# How many features will be dropped?

# %%
len(drop_list)
# Out:
# 58

# %% [markdown]
# Now drop these features.

# %%
loans.drop(labels=drop_list, axis=1, inplace=True)

# %% [markdown]
# ## Remove features that were unavailable before the loan was funded
# <a id="4.4"></a>

# %% [markdown]
# We examine the Lending Club Data Dictionary to determine which features would not have been available before the loan was funded. The idea here is to predict whether a loan will be paid off **before** deciding to fund the loan. Here's the list of features we currently have, in alphabetical order:

# %%
print(sorted(list(loans.columns)))
# Out:
# ['acc_now_delinq', 'acc_open_past_24mths', 'addr_state', 'annual_inc', 'application_type', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'collection_recovery_fee', 'collections_12_mths_ex_med', 'debt_settlement_flag', 'delinq_2yrs', 'delinq_amnt', 'disbursement_method', 'dti', 'earliest_cr_line', 'emp_length', 'emp_title', 'fico_range_high', 'fico_range_low', 'funded_amnt', 'funded_amnt_inv', 'grade', 'hardship_flag', 'home_ownership', 'id', 'initial_list_status', 'inq_last_6mths', 'installment', 'int_rate', 'issue_d', 'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low', 'last_pymnt_amnt', 'last_pymnt_d', 'loan_amnt', 'loan_status', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_inq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'open_acc', 'out_prncp', 'out_prncp_inv', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'policy_code', 'pub_rec', 'pub_rec_bankruptcies', 'purpose', 'pymnt_plan', 'recoveries', 'revol_bal', 'revol_util', 'sub_grade', 'tax_liens', 'term', 'title', 'tot_coll_amt', 'tot_cur_bal', 'tot_hi_cred_lim', 'total_acc', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 'total_pymnt', 'total_pymnt_inv', 'total_rec_int', 'total_rec_late_fee', 'total_rec_prncp', 'total_rev_hi_lim', 'verification_status', 'zip_code']

# %% [markdown]
# For each of these features, we check the description in the Data Dictionary, and drop those features that we believe would not have been available before the loan was funded. When in doubt, we err on the side of dropping the feature.

# %%
drop_list = ['acc_now_delinq', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'collection_recovery_fee', 'collections_12_mths_ex_med', 'debt_settlement_flag', 'delinq_2yrs', 'delinq_amnt', 'disbursement_method', 'funded_amnt', 'funded_amnt_inv', 'hardship_flag', 'inq_last_6mths', 'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low', 'last_pymnt_amnt', 'last_pymnt_d', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mths_since_recent_bc', 'mths_since_recent_inq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'open_acc', 'out_prncp', 'out_prncp_inv', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pymnt_plan', 'recoveries', 'revol_bal', 'revol_util', 'tax_liens', 'tot_coll_amt', 'tot_cur_bal', 'tot_hi_cred_lim', 'total_acc', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 'total_pymnt', 'total_pymnt_inv', 'total_rec_int', 'total_rec_late_fee', 'total_rec_prncp', 'total_rev_hi_lim']

# %% [markdown]
# How many features will be dropped?

# %%
len(drop_list)
# Out:
# 62

# %% [markdown]
# Drop these features:

# %%
loans.drop(labels=drop_list, axis=1, inplace=True)

# %% [markdown]
# ## Inspect the remaining features

# %% [markdown]
# We'll inspect each feature individually, and do the following:
#
# 1. View summary statistics and visualize the data, if desired.
# 2. Modify the feature to make it useful for modeling, if necessary.
# 3. Drop the feature if it can't be made useful for modeling.

# %% [markdown]
# Define a plotting utility:

# %%
def plot_var(col_name, full_name, continuous):
    """
    Visualize a variable with and without faceting on the loan status.
    - col_name is the variable name in the dataframe
    - full_name is the full variable name
    - continuous is True if the variable is continuous, False otherwise
    """
    f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,3), dpi=90)
    
    # Plot without loan status
    if continuous:
        sns.distplot(loans.loc[loans[col_name].notnull(), col_name], kde=False, ax=ax1)
    else:
        sns.countplot(loans[col_name], order=sorted(loans[col_name].unique()), color='#5975A4', saturation=1, ax=ax1)
    ax1.set_xlabel(full_name)
    ax1.set_ylabel('Count')
    ax1.set_title(full_name)

    # Plot with loan status
    if continuous:
        sns.boxplot(x=col_name, y='loan_status', data=loans, ax=ax2)
        ax2.set_ylabel('')
        ax2.set_title(full_name + ' by Loan Status')
    else:
        charge_off_rates = loans.groupby(col_name)['loan_status'].value_counts(normalize=True).loc[:,'Charged Off']
        sns.barplot(x=charge_off_rates.index, y=charge_off_rates.values, color='#5975A4', saturation=1, ax=ax2)
        ax2.set_ylabel('Fraction of Loans Charged Off')
        ax2.set_title('Charge Off Rate by ' + full_name)
    ax2.set_xlabel(full_name)
    
    plt.tight_layout()

# %% [markdown]
# How many features are left?

# %%
loans.shape[1]
# Out:
# 30

# %% [markdown]
# What are the remaining features?

# %%
print(list(loans.columns))
# Out:
# ['id', 'loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'purpose', 'title', 'zip_code', 'addr_state', 'dti', 'earliest_cr_line', 'fico_range_low', 'fico_range_high', 'pub_rec', 'initial_list_status', 'policy_code', 'application_type', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mort_acc', 'pub_rec_bankruptcies']

# %% [markdown]
# ### id

# %% [markdown]
# Data Dictionary: "A unique [Lending Club] assigned ID for the loan listing."

# %%
loans['id'].sample(5)
# Out:
# 940045      2574791
# 1079550    96529367
# 945273      2174913
# 883691      5936558
# 198435     11375451
# Name: id, dtype: object

# %% [markdown]
#  Are all the IDs in fact unique?

# %%
loans['id'].describe()
# Out:
# count       814986
# unique      814986
# top       14680062
# freq             1
# Name: id, dtype: int64

# %% [markdown]
# The ID is not useful for modeling, either as a categorical variable (there are too many distinct values) or as a numerical variable (the IDs vary wildly in magnitude, likely without any significance), so we drop this variable.

# %%
loans.drop('id', axis=1, inplace=True)

# %% [markdown]
# ### loan_amnt

# %% [markdown]
# Data Dictionary: "The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value."

# %%
loans['loan_amnt'].describe()
# Out:
# count    814986.000000
# mean      14315.458210
# std        8499.799241
# min         500.000000
# 25%        8000.000000
# 50%       12000.000000
# 75%       20000.000000
# max       40000.000000
# Name: loan_amnt, dtype: float64

# %% [markdown]
# Loan amounts range from \$500 to \$40,000, with a median of \$12,000.

# %%
plot_var('loan_amnt', 'Loan Amounts', continuous=True)
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# Charged-off loans tend to have higher loan amounts. Because of the large number of samples, the difference in the medians is likely to be statistically significant.

# %% [markdown]
# ### term

# %% [markdown]
# Data Dictionary: "The number of payments on the loan. Values are in months and can be either 36 or 60."
#
# Let's check the value counts:

# %%
loans['term'].value_counts(dropna=False)
# Out:
#  36 months    618460
#  60 months    196526
# Name: term, dtype: int64

# %% [markdown]
# Convert `term` to integers.

# %%
loans.loc[:,'term'] = loans['term'].apply(lambda s: np.int8(s.split()[0]))

# %%
loans['term'].value_counts(normalize=True)
# Out:
# 36    0.75886
# 60    0.24114
# Name: term, dtype: float64

# %%
plot_var('term', 'Term', continuous=False)

# %% [markdown]
# About 76% of loans are 36 months, and the rest are 60 months. Loans with 60-month terms are less likely to be fully paid.

# %% [markdown]
# ### int_rate

# %% [markdown]
# Data Dictionary: "Interest Rate on the loan."

# %%
loans['int_rate'].describe()
# Out:
# count    814986.000000
# mean         13.490993
# std           4.618486
# min           5.320000
# 25%           9.990000
# 50%          13.110000
# 75%          16.290000
# max          30.990000
# Name: int_rate, dtype: float64

# %% [markdown]
# Interest rates range from 5.3% to 30.9% (!), with a median of 13.1%.

# %%
plot_var('int_rate', 'Interest Rate', continuous=True)
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# Charged-off loans tend to have higher interest rates.

# %% [markdown]
# ### installment

# %% [markdown]
# Data Dictionary: "The monthly payment owed by the borrower if the loan originates."

# %%
loans['installment'].describe()
# Out:
# count    814986.000000
# mean        436.749624
# std         255.732093
# min           4.930000
# 25%         251.400000
# 50%         377.040000
# 75%         576.290000
# max        1714.540000
# Name: installment, dtype: float64

# %% [markdown]
# Installments range from \$4.93 to \$1,714, with a median of \$377.

# %%
plot_var('installment', 'Installment', continuous=True)
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# Charged-off loans tend to have slightly higher installments.

# %% [markdown]
# ### grade, sub_grade

# %% [markdown]
# Data Dictionary for `grade`: "[Lending Club] assigned loan grade."
#
# Data Dictionary for `sub_grade`: "LC assigned loan subgrade."
#
# What are the possible values of `grade` and `sub_grade`?

# %%
print(sorted(loans['grade'].unique()))
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
print(sorted(loans['sub_grade'].unique()))
# Out:
# ['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1', 'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2', 'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3', 'G4', 'G5']

# %% [markdown]
# The grade is implied by the subgrade, so let's drop the grade column.

# %%
loans.drop('grade', axis=1, inplace=True)

# %%
plot_var('sub_grade', 'Subgrade', continuous=False)

# %% [markdown]
# There's a clear trend of higher probability of charge-off as the subgrade worsens.

# %% [markdown]
# ### emp_title

# %% [markdown]
# Data Dictionary: "The job title supplied by the Borrower when applying for the loan."

# %%
loans['emp_title'].describe()
# Out:
# count      766415
# unique     280473
# top       Teacher
# freq        11351
# Name: emp_title, dtype: object

# %%
loans.shape[0]
# Out:
# 814986

# %% [markdown]
# There are too many different job titles for this feature to be useful, so we drop it.

# %%
loans.drop(labels='emp_title', axis=1, inplace=True)

# %% [markdown]
# ### emp_length

# %% [markdown]
# Data Dictionary: "Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years." The actual data does not match this description:

# %%
loans['emp_length'].value_counts(dropna=False).sort_index()
# Out:
# 1 year        53411
# 10+ years    264873
# 2 years       73493
# 3 years       64999
# 4 years       48752
# 5 years       52149
# 6 years       40290
# 7 years       39407
# 8 years       38887
# 9 years       31900
# < 1 year      64572
# NaN           42253
# Name: emp_length, dtype: int64

# %% [markdown]
# Note there are 42,253 loans without data on the length of employment.
#
# Convert `emp_length` to integers:

# %%
loans['emp_length'].replace(to_replace='10+ years', value='10 years', inplace=True)

# %%
loans['emp_length'].replace('< 1 year', '0 years', inplace=True)

# %%
def emp_length_to_int(s):
    if pd.isnull(s):
        return s
    else:
        return np.int8(s.split()[0])

# %%
loans['emp_length'] = loans['emp_length'].apply(emp_length_to_int)

# %%
loans['emp_length'].value_counts(dropna=False).sort_index()
# Out:
#  0.0      64572
#  1.0      53411
#  2.0      73493
#  3.0      64999
#  4.0      48752
#  5.0      52149
#  6.0      40290
#  7.0      39407
#  8.0      38887
#  9.0      31900
#  10.0    264873
# NaN       42253
# Name: emp_length, dtype: int64

# %%
plot_var('emp_length', 'Employment length', continuous=False)

# %% [markdown]
# Loan status does not appear to depend much at all on employment length.

# %% [markdown]
# ### home_ownership

# %% [markdown]
# Data Dictionary: "The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER."

# %%
loans['home_ownership'].value_counts(dropna=False)
# Out:
# MORTGAGE    406866
# RENT        325071
# OWN          82765
# OTHER          144
# ANY             94
# NONE            46
# Name: home_ownership, dtype: int64

# %% [markdown]
# Replace ANY and NONE with OTHER, so that we have enough observations of each category.

# %%
loans['home_ownership'].replace(['NONE', 'ANY'], 'OTHER', inplace=True)

# %%
loans['home_ownership'].value_counts(dropna=False)
# Out:
# MORTGAGE    406866
# RENT        325071
# OWN          82765
# OTHER          284
# Name: home_ownership, dtype: int64

# %%
plot_var('home_ownership', 'Home Ownership', continuous=False)

# %% [markdown]
# There appear to be small differences in charge-off rates by home ownership status. Renters have slightly less probability of fully paying off the loan. Because of the large numbers of observations in each category, these differences are statistically significant.

# %% [markdown]
# ### annual_inc

# %% [markdown]
# Data Dictionary: "The self-reported annual income provided by the borrower during registration."

# %%
loans['annual_inc'].describe()
# Out:
# count    8.149860e+05
# mean     7.523039e+04
# std      6.524373e+04
# min      0.000000e+00
# 25%      4.500000e+04
# 50%      6.500000e+04
# 75%      9.000000e+04
# max      9.550000e+06
# Name: annual_inc, dtype: float64

# %% [markdown]
# Annual income ranges from \$0 to \$9,550,000, with a median of \$65,000. (Note this is more than double the national median individual income in the US.)
#
# Because of the large range of incomes, we should take a log transform of the annual income.

# %%
loans['annual_inc'] = loans['annual_inc'].apply(lambda x: np.log10(x+1))

# %%
loans['annual_inc'].describe()
# Out:
# count    814986.000000
# mean          4.810836
# std           0.231893
# min           0.000000
# 25%           4.653222
# 50%           4.812920
# 75%           4.954247
# max           6.980003
# Name: annual_inc, dtype: float64

# %%
plot_var('annual_inc', 'Log Annual Income', continuous=True)
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# It appears that individuals with somewhat higher income are more likely to pay off their loans. Let's break this down:

# %%
loans.groupby('loan_status')['annual_inc'].describe()
# Out:
#                 count      mean       std  min       25%       50%       75%  \
# loan_status
# Charged Off  168084.0  4.777072  0.227015  0.0  4.632467  4.778158  4.915096
# Fully Paid   646902.0  4.819608  0.232342  0.0  4.672107  4.812920  4.963793
#
#                   max
# loan_status
# Charged Off  6.949393
# Fully Paid   6.980003

# %% [markdown]
# There is a small, but likely statistically significant difference in the medians.

# %% [markdown]
# ### verification_status

# %% [markdown]
# Data Dictionary: "Indicates if income was verified by [Lending Club], not verified, or if the income source was verified."

# %%
loans['verification_status'].value_counts(dropna=False)
# Out:
# Source Verified    293897
# Verified           269895
# Not Verified       251194
# Name: verification_status, dtype: int64

# %%
plot_var('verification_status', 'Verification Status', continuous=False)

# %% [markdown]
# ### issue_d

# %% [markdown]
# Data Dictionary: "The month which the loan was funded."
#
# Because we're only using variables available before the loan was funded, `issue_d` will not be included in the final model. We're keeping it for now just to perform the train/test split later, then we'll drop it.

# %% [markdown]
# ### purpose

# %% [markdown]
# Data Dictionary: "A category provided by the borrower for the loan request."

# %%
loans['purpose'].value_counts()
# Out:
# debt_consolidation    481652
# credit_card           175123
# home_improvement       50793
# other                  43900
# major_purchase         17463
# small_business         10214
# car                     8936
# medical                 8772
# moving                  5725
# vacation                5116
# house                   4095
# wedding                 2272
# renewable_energy         599
# educational              326
# Name: purpose, dtype: int64

# %% [markdown]
# Calculate the fully-paid rates by purpose:

# %%
loans.groupby('purpose')['loan_status'].value_counts(normalize=True).loc[:,'Charged Off'].sort_values(ascending=False)
# Out:
# purpose
# small_business        0.302428
# renewable_energy      0.247078
# moving                0.242969
# medical               0.229366
# debt_consolidation    0.217398
# other                 0.216970
# house                 0.214652
# vacation              0.198788
# major_purchase        0.183245
# home_improvement      0.181383
# credit_card           0.178412
# educational           0.171779
# car                   0.148053
# wedding               0.121919
# Name: loan_status, dtype: float64

# %% [markdown]
# We see that, for example, 87.8% of loans for weddings are fully paid, but only 69.7% of small business loans are fully paid.

# %% [markdown]
# ### title

# %% [markdown]
# Data Dictionary: "The loan title provided by the borrower."

# %%
loans['title'].sample(5)
# Out:
# 86294      Credit card refinancing
# 697978            Home improvement
# 28811      Credit card refinancing
# 1043104      Moving and relocation
# 603075          Debt consolidation
# Name: title, dtype: object

# %%
loans['title'].describe()
# Out:
# count                 807068
# unique                 60298
# top       Debt consolidation
# freq                  371874
# Name: title, dtype: object

# %% [markdown]
# View the top 10 loan titles, and their frequencies:

# %%
loans['title'].value_counts().head(10)
# Out:
# Debt consolidation         371874
# Credit card refinancing    133334
# Home improvement            39171
# Other                       33265
# Debt Consolidation          15059
# Major purchase              12311
# Medical expenses             6908
# Business                     6666
# Car financing                5667
# Consolidation                5090
# Name: title, dtype: int64

# %% [markdown]
# There are 60,298 different purposes in the dataset, and based on the top 10 titles, the `purpose` variable appears to already contain this information. So we drop the `title` variable.

# %%
loans.drop(labels='title', axis=1, inplace=True)

# %% [markdown]
# ### zip_code, addr_state

# %% [markdown]
# Data Dictionary for `zip_code`: "The first 3 numbers of the zip code provided by the borrower in the loan application."
#
# Data Dictionary for `addr_state`: "The state provided by the borrower in the loan application."

# %%
loans['zip_code'].sample(5)
# Out:
# 199134    070xx
# 143601    917xx
# 989339    119xx
# 30354     435xx
# 233522    984xx
# Name: zip_code, dtype: object

# %%
loans['zip_code'].nunique()
# Out:
# 925

# %%
loans['addr_state'].sample(5)
# Out:
# 89822      CA
# 1337284    CT
# 554184     OR
# 883861     WI
# 640559     IL
# Name: addr_state, dtype: object

# %%
loans['addr_state'].nunique()
# Out:
# 51

# %% [markdown]
# There are a lot of different zip codes, so let's just retain the state column.

# %%
loans.drop(labels='zip_code', axis=1, inplace=True)

# %% [markdown]
# Calculate the fully-paid rates by address state:

# %%
loans.groupby('addr_state')['loan_status'].value_counts(normalize=True).loc[:,'Charged Off'].sort_values(ascending=False)
# Out:
# addr_state
# MS    0.275619
# NE    0.267946
# OK    0.248252
# AL    0.247650
# AR    0.243154
# LA    0.237900
# ND    0.237232
# NV    0.234202
# TN    0.230479
# IN    0.228179
# NY    0.227045
# SD    0.225787
# NM    0.225694
# OH    0.225400
# FL    0.222007
# MO    0.219400
# KY    0.216353
# NJ    0.216208
# NC    0.215282
# MD    0.214845
# PA    0.214776
# MN    0.210363
# MI    0.208880
# VA    0.207942
# DE    0.206575
# HI    0.204535
# AK    0.204141
# TX    0.202286
# AZ    0.199321
# CA    0.198303
# RI    0.194009
# ID    0.193487
# IL    0.193302
# MA    0.192974
# GA    0.191224
# CT    0.183810
# WV    0.182457
# UT    0.179049
# WY    0.178142
# MT    0.177759
# WI    0.175315
# SC    0.172705
# KS    0.171004
# WA    0.166538
# CO    0.158083
# OR    0.152827
# VT    0.149225
# IA    0.142857
# NH    0.142554
# ME    0.136564
# DC    0.130378
# Name: loan_status, dtype: float64

# %% [markdown]
# The percentages of loans fully paid ranges from 72.4% in Mississippi to 86.9% in Washington, DC.

# %% [markdown]
# ### dti

# %% [markdown]
# Data Dictionary: "A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income."

# %%
loans['dti'].describe()
# Out:
# count    814950.000000
# mean         17.867719
# std           8.856477
# min          -1.000000
# 25%          11.640000
# 50%          17.360000
# 75%          23.630000
# max         999.000000
# Name: dti, dtype: float64

# %% [markdown]
# Note sure if the values of -1 and 999 make sense...
#
# There are several outliers that mess up our default plots. Plot a histogram for `dti` less than 60:

# %%
plt.figure(figsize=(8,3), dpi=90)
sns.distplot(loans.loc[loans['dti'].notnull() & (loans['dti']<60), 'dti'], kde=False)
plt.xlabel('Debt-to-income')
plt.ylabel('Count')
plt.title('Debt-to-income')
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Debt-to-income')

# %% [markdown]
# How many of the `dti` values are "outliers" (above 60)?

# %%
(loans['dti']>=60).sum()
# Out:
# 179

# %% [markdown]
# Very few.

# %% [markdown]
# Compare the `dti` medians for fully paid and charged-off loans:

# %%
loans.groupby('loan_status')['dti'].median()
# Out:
# loan_status
# Charged Off    19.77
# Fully Paid     16.77
# Name: dti, dtype: float64

# %% [markdown]
# Borrowers who charge off tend to have higher debt-to-income ratios.

# %% [markdown]
# ### earliest_cr_line

# %% [markdown]
# Data Dictionary: "The month the borrower's earliest reported credit line was opened."

# %%
loans['earliest_cr_line'].sample(5)
# Out:
# 1393254    Jun-1990
# 808935     Aug-2003
# 171402     Nov-2000
# 141476     Mar-1996
# 1107       Oct-2003
# Name: earliest_cr_line, dtype: object

# %%
loans['earliest_cr_line'].isnull().any()
# Out:
# False

# %% [markdown]
# Let's just retain the year for simplicity:

# %%
loans['earliest_cr_line'] = loans['earliest_cr_line'].apply(lambda s: int(s[-4:]))

# %%
loans['earliest_cr_line'].describe()
# Out:
# count    814986.000000
# mean       1998.170962
# std           7.385629
# min        1944.000000
# 25%        1994.000000
# 50%        2000.000000
# 75%        2003.000000
# max        2014.000000
# Name: earliest_cr_line, dtype: float64

# %%
plot_var('earliest_cr_line', 'Year of Earliest Credit Line', continuous=True)
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# Borrowers who charge off tend to have opened their first credit line more recently.

# %% [markdown]
# ### fico_range_low, fico_range_high

# %% [markdown]
# Data Dictionary for `fico_range_low`: "The lower boundary range the borrower’s FICO at loan origination belongs to."
#
# Data Dictionary for `fico_range_high`: "The upper boundary range the borrower’s FICO at loan origination belongs to."

# %%
loans[['fico_range_low', 'fico_range_high']].describe()
# Out:
#        fico_range_low  fico_range_high
# count   814986.000000    814986.000000
# mean       695.603151       699.603264
# std         31.352251        31.352791
# min        625.000000       629.000000
# 25%        670.000000       674.000000
# 50%        690.000000       694.000000
# 75%        710.000000       714.000000
# max        845.000000       850.000000

# %% [markdown]
# Check the correlation between these values:

# %%
loans[['fico_range_low','fico_range_high']].corr()
# Out:
#                  fico_range_low  fico_range_high
# fico_range_low              1.0              1.0
# fico_range_high             1.0              1.0

# %% [markdown]
# We only need to keep one of the FICO scores.

# %%
loans.drop(labels='fico_range_low', axis=1, inplace=True)

# %%
plot_var('fico_range_high', 'FICO Range High', continuous=True)
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# There is a noticeable difference in FICO scores between fully paid and charged-off loans.

# %% [markdown]
# ### pub_rec

# %% [markdown]
# Data Dictionary: "Number of derogatory public records."

# %%
loans['pub_rec'].value_counts()
# Out:
# 0.0     681509
# 1.0     112483
# 2.0      14115
# 3.0       4107
# 4.0       1400
# 5.0        651
# 6.0        338
# 7.0        146
# 8.0         90
# 9.0         42
# 10.0        28
# 11.0        24
# 12.0        15
# 13.0        11
# 15.0         5
# 18.0         3
# 16.0         2
# 19.0         2
# 14.0         2
# 49.0         2
# 28.0         2
# 34.0         1
# 24.0         1
# 46.0         1
# 54.0         1
# 63.0         1
# 17.0         1
# 21.0         1
# 86.0         1
# 40.0         1
# Name: pub_rec, dtype: int64

# %% [markdown]
# Is there a difference in average public records between fully paid loans and charged-off loans?

# %%
loans.groupby('loan_status')['pub_rec'].mean()
# Out:
# loan_status
# Charged Off    0.232247
# Fully Paid     0.198845
# Name: pub_rec, dtype: float64

# %% [markdown]
# ### initial_list_status

# %% [markdown]
# Data Dictionary: "The initial listing status of the loan. Possible values are – W, F." I'm not sure what this means.

# %%
loans['initial_list_status'].value_counts()
# Out:
# f    413678
# w    401308
# Name: initial_list_status, dtype: int64

# %%
plot_var('initial_list_status', 'Initial List Status', continuous=False)

# %% [markdown]
# ### policy_code

# %% [markdown]
# Data Dictionary: "publicly available policy_code=1; new products not publicly available policy_code=2"

# %%
loans['policy_code'].value_counts()
# Out:
# 1.0    814986
# Name: policy_code, dtype: int64

# %% [markdown]
# All values are the same; drop this variable.

# %%
loans.drop(labels='policy_code', axis=1, inplace=True)

# %% [markdown]
# ### application_type

# %% [markdown]
# Data Dictionary: "Indicates whether the loan is an individual application or a joint application with two co-borrowers."

# %%
loans['application_type'].value_counts()
# Out:
# Individual    811207
# Joint App       3779
# Name: application_type, dtype: int64

# %%
plot_var('application_type', 'Application Type', continuous=False)

# %% [markdown]
# Joint loans are slightly more likely to be fully paid, but because there are few joint apps, it's unclear at the moment whether the difference is statistically significant.

# %% [markdown]
# ### mo_sin_old_il_acct

# %% [markdown]
# Data Dictionary: "Months since oldest bank installment account opened."

# %%
loans['mo_sin_old_il_acct'].describe()
# Out:
# count    725427.000000
# mean        125.926232
# std          51.554620
# min           0.000000
# 25%          98.000000
# 50%         129.000000
# 75%         152.000000
# max         724.000000
# Name: mo_sin_old_il_acct, dtype: float64

# %%
plot_var('mo_sin_old_il_acct', 'Months since Oldest Installment Account', continuous=True)
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### mo_sin_old_rev_tl_op

# %% [markdown]
# Data Dictionary: "Months since oldest revolving account opened."

# %%
loans['mo_sin_old_rev_tl_op'].describe()
# Out:
# count    747458.000000
# mean        180.843182
# std          92.192939
# min           2.000000
# 25%         117.000000
# 50%         164.000000
# 75%         228.000000
# max         842.000000
# Name: mo_sin_old_rev_tl_op, dtype: float64

# %%
plot_var('mo_sin_old_rev_tl_op', 'Months since Oldest Revolving Account', continuous=True)
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### mort_acc

# %% [markdown]
# Data Dictionary: "Number of mortgage accounts."

# %%
loans['mort_acc'].describe()
# Out:
# count    767705.000000
# mean          1.758707
# std           2.081730
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           3.000000
# max          51.000000
# Name: mort_acc, dtype: float64

# %% [markdown]
# Not sure how someone can have 51 mortgage accounts...but apparently they do.

# %% [markdown]
# Top 10 values:

# %%
loans['mort_acc'].value_counts().head(10)
# Out:
# 0.0    301446
# 1.0    131811
# 2.0    109869
# 3.0     82723
# 4.0     58698
# 5.0     37090
# 6.0     21817
# 7.0     11568
# 8.0      5906
# 9.0      3056
# Name: mort_acc, dtype: int64

# %%
plot_var('mort_acc', 'Number of Mortgage Accounts', continuous=True)
# Out:
# C:\Users\Joe\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# Compare the averages by loan status:

# %%
loans.groupby('loan_status')['mort_acc'].mean()
# Out:
# loan_status
# Charged Off    1.447437
# Fully Paid     1.841436
# Name: mort_acc, dtype: float64

# %% [markdown]
# Individuals who pay off their loans tend to have more mortgage accounts on average.

# %% [markdown]
# ### pub_rec_bankruptcies

# %% [markdown]
# Data Dictionary: "Number of public record bankruptcies."

# %%
loans['pub_rec_bankruptcies'].value_counts().sort_index()
# Out:
# 0.0     714642
# 1.0      93680
# 2.0       4673
# 3.0        926
# 4.0        234
# 5.0         85
# 6.0         28
# 7.0         14
# 8.0          5
# 9.0          1
# 12.0         1
# Name: pub_rec_bankruptcies, dtype: int64

# %%
plot_var('pub_rec_bankruptcies', 'Public Record Bankruptcies', continuous=False)

# %% [markdown]
# # More Pre-processing

# %% [markdown]
# ## Convert Loan Status to Binary

# %% [markdown]
# Change the response variable `loan_status` to a 0/1 variable, where 0 indicates fully paid and 1 indicates charge-off:

# %%
loans['charged_off'] = (loans['loan_status'] == 'Charged Off').apply(np.uint8)
loans.drop('loan_status', axis=1, inplace=True)

# %% [markdown]
# ## Create Dummy Variables

# %% [markdown]
# How many variables do we currently have?

# %%
loans.shape[1]
# Out:
# 23

# %% [markdown]
# Which variables have missing values?

# %%
missing_fractions = loans.isnull().mean().sort_values(ascending=False)

# %%
missing_fractions[missing_fractions > 0]
# Out:
# mo_sin_old_il_acct      0.109890
# mo_sin_old_rev_tl_op    0.082858
# mort_acc                0.058014
# emp_length              0.051845
# pub_rec_bankruptcies    0.000855
# dti                     0.000044
# dtype: float64

# %% [markdown]
# There are no categorical variables with missing values, and therefore we don't need any `NaN` dummy variables.
#
# Create dummy variables for the categorical variables:

# %%
loans = pd.get_dummies(loans, columns=['sub_grade', 'home_ownership', 'verification_status', 'purpose', 'addr_state', 'initial_list_status', 'application_type'], drop_first=True)

# %%
loans.shape
# Out:
# (814986, 120)

# %% [markdown]
# Check our data with the new dummy variables:

# %%
loans.sample(3)
# Out:
#         loan_amnt  term  int_rate  installment  emp_length  annual_inc  \
# 564170     5400.0    36     12.29       180.11         0.0    4.732402
# 620969    25600.0    36      5.93       777.99        10.0    5.152291
# 894656     4000.0    36     17.77       144.15         0.0    4.845104
#
#          issue_d    dti  earliest_cr_line  fico_range_high  pub_rec  \
# 564170  May-2015  28.67              2004            679.0      0.0
# 620969  Mar-2015  11.48              1995            694.0      0.0
# 894656  Jun-2013   9.03              2005            679.0      0.0
#
#         mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mort_acc  \
# 564170               126.0                 105.0       1.0
# 620969               236.0                 216.0       6.0
# 894656                77.0                  95.0       4.0
#
#         pub_rec_bankruptcies  charged_off  sub_grade_A2  sub_grade_A3  \
# 564170                   0.0            0             0             0
# 620969                   0.0            0             0             0
# 894656                   0.0            0             0             0
#
#         sub_grade_A4  sub_grade_A5  sub_grade_B1  sub_grade_B2  sub_grade_B3  \
# 564170             0             0             0             0             0
# 620969             0             0             0             0             0
# 894656             0             0             0             0             0
#
#         sub_grade_B4  sub_grade_B5  sub_grade_C1  sub_grade_C2  sub_grade_C3  \
# 564170             0             0             1             0             0
# 620969             0             0             0             0             0
# 894656             0             0             0             0             0
#
#         sub_grade_C4  sub_grade_C5  sub_grade_D1  sub_grade_D2  sub_grade_D3  \
# 564170             0             0             0             0             0
# 620969             0             0             0             0             0
# 894656             0             0             1             0             0
#
#         sub_grade_D4  sub_grade_D5  sub_grade_E1  sub_grade_E2  sub_grade_E3  \
# 564170             0             0             0             0             0
# 620969             0             0             0             0             0
# 894656             0             0             0             0             0
#
#         sub_grade_E4  sub_grade_E5  sub_grade_F1  sub_grade_F2  sub_grade_F3  \
# 564170             0             0             0             0             0
# 620969             0             0             0             0             0
# 894656             0             0             0             0             0
#
#         sub_grade_F4  sub_grade_F5  sub_grade_G1  sub_grade_G2  sub_grade_G3  \
# 564170             0             0             0             0             0
# 620969             0             0             0             0             0
# 894656             0             0             0             0             0
#
#         sub_grade_G4  sub_grade_G5  home_ownership_OTHER  home_ownership_OWN  \
# 564170             0             0                     0                   0
# 620969             0             0                     0                   0
# 894656             0             0                     0                   1
#
#         home_ownership_RENT  verification_status_Source Verified  \
# 564170                    0                                    0
# 620969                    0                                    0
# 894656                    0                                    0
#
#         verification_status_Verified  purpose_credit_card  \
# 564170                             0                    1
# 620969                             1                    1
# 894656                             0                    0
#
#         purpose_debt_consolidation  purpose_educational  \
# 564170                           0                    0
# 620969                           0                    0
# 894656                           0                    0
#
#         purpose_home_improvement  purpose_house  purpose_major_purchase  \
# 564170                         0              0                       0
# 620969                         0              0                       0
# 894656                         0              0                       0
#
#         purpose_medical  purpose_moving  purpose_other  \
# 564170                0               0              0
# 620969                0               0              0
# 894656                0               0              1
#
#         purpose_renewable_energy  purpose_small_business  purpose_vacation  \
# 564170                         0                       0                 0
# 620969                         0                       0                 0
# 894656                         0                       0                 0
#
#         purpose_wedding  addr_state_AL  addr_state_AR  addr_state_AZ  \
# 564170                0              0              0              0
# 620969                0              0              0              0
# 894656                0              0              0              0
#
#         addr_state_CA  addr_state_CO  addr_state_CT  addr_state_DC  \
# 564170              0              0              0              0
# 620969              0              0              0              0
# 894656              0              0              0              0
#
#         addr_state_DE  addr_state_FL  addr_state_GA  addr_state_HI  \
# 564170              0              0              0              0
# 620969              0              0              0              0
# 894656              0              0              0              0
#
#         addr_state_IA  addr_state_ID  addr_state_IL  addr_state_IN  \
# 564170              0              0              0              0
# 620969              0              0              0              0
# 894656              0              0              0              0
#
#         addr_state_KS  addr_state_KY  addr_state_LA  addr_state_MA  \
# 564170              0              0              0              0
# 620969              0              0              0              1
# 894656              0              0              0              0
#
#         addr_state_MD  addr_state_ME  addr_state_MI  addr_state_MN  \
# 564170              0              0              0              0
# 620969              0              0              0              0
# 894656              0              0              0              0
#
#         addr_state_MO  addr_state_MS  addr_state_MT  addr_state_NC  \
# 564170              0              0              0              0
# 620969              0              0              0              0
# 894656              1              0              0              0
#
#         addr_state_ND  addr_state_NE  addr_state_NH  addr_state_NJ  \
# 564170              0              0              0              0
# 620969              0              0              0              0
# 894656              0              0              0              0
#
#         addr_state_NM  addr_state_NV  addr_state_NY  addr_state_OH  \
# 564170              0              0              0              0
# 620969              0              0              0              0
# 894656              0              0              0              0
#
#         addr_state_OK  addr_state_OR  addr_state_PA  addr_state_RI  \
# 564170              0              0              1              0
# 620969              0              0              0              0
# 894656              0              0              0              0
#
#         addr_state_SC  addr_state_SD  addr_state_TN  addr_state_TX  \
# 564170              0              0              0              0
# 620969              0              0              0              0
# 894656              0              0              0              0
#
#         addr_state_UT  addr_state_VA  addr_state_VT  addr_state_WA  \
# 564170              0              0              0              0
# 620969              0              0              0              0
# 894656              0              0              0              0
#
#         addr_state_WI  addr_state_WV  addr_state_WY  initial_list_status_w  \
# 564170              0              0              0                      0
# 620969              0              0              0                      1
# 894656              0              0              0                      0
#
#         application_type_Joint App
# 564170                           0
# 620969                           0
# 894656                           0

# %% [markdown]
# Looks good!

# %% [markdown]
# ## Train/test split

# %% [markdown]
# We'll make our predictions more realistic by performing the train/test split based on the month that the loan was funded. That is, we'll use loans funded on earlier dates to predict the outcome of loans funded on later dates.
#
# The variable `issue_d` includes the month which the loan was funded. Let's peek at this variable:

# %%
loans['issue_d'].sample(5)
# Out:
# 168693     May-2014
# 450128     Aug-2015
# 112165     Jul-2014
# 471143     Aug-2015
# 1162622    Jul-2016
# Name: issue_d, dtype: object

# %% [markdown]
# So `issue_d` only includes month and year data. Are there any missing values?

# %%
loans['issue_d'].isnull().any()
# Out:
# False

# %% [markdown]
# No. Let's convert the issue dates to datetime objects:

# %%
loans['issue_d'] = pd.to_datetime(loans['issue_d'])

# %%
loans['issue_d'].sample(5)
# Out:
# 984129   2012-04-01
# 215489   2014-02-01
# 21279    2014-11-01
# 668871   2015-01-01
# 887717   2013-06-01
# Name: issue_d, dtype: datetime64[ns]

# %% [markdown]
# The `issue_d` values got converted to dates, all on the first day of the month. Check summary statistics of the issue dates:

# %%
loans['issue_d'].describe()
# Out:
# count                  814986
# unique                    124
# top       2014-10-01 00:00:00
# freq                    33699
# first     2007-06-01 00:00:00
# last      2017-09-01 00:00:00
# Name: issue_d, dtype: object

# %% [markdown]
# Note there are only 124 unique issue dates over the 10-year period because we only have month/year information. In this particular dataset, the first loans were issued in June 2007, and the most recent loans were issued in September 2017. The busiest month was October 2014 with 33,699 loans funded in that month. What is the distribution of loans funded per year?

# %%
plt.figure(figsize=(6,3), dpi=90)
loans['issue_d'].dt.year.value_counts().sort_index().plot.bar(color='darkblue')
plt.xlabel('Year')
plt.ylabel('Number of loans funded')
plt.title('Loans Funded per Year')
# Out:
# Text(0.5,1,'Loans Funded per Year')

# %% [markdown]
# We'll form the test set from the most recent 10% of the loans.

# %%
loans_train = loans.loc[loans['issue_d'] <  loans['issue_d'].quantile(0.9)]
loans_test =  loans.loc[loans['issue_d'] >= loans['issue_d'].quantile(0.9)]

# %% [markdown]
# Check that we properly partitioned the loans:

# %%
print('Number of loans in the partition:   ', loans_train.shape[0] + loans_test.shape[0])
print('Number of loans in the full dataset:', loans.shape[0])
# Out:
# Number of loans in the partition:    814986
# Number of loans in the full dataset: 814986

# %% [markdown]
# The partition looks good, so we can delete the original `loans` dataframe.

# %%
del loans

# %% [markdown]
# Let's look at the summary statistics of the issue dates in the train/validation/test sets:

# %%
loans_train['issue_d'].describe()
# Out:
# count                  731108
# unique                    109
# top       2014-10-01 00:00:00
# freq                    33699
# first     2007-06-01 00:00:00
# last      2016-06-01 00:00:00
# Name: issue_d, dtype: object

# %%
loans_test['issue_d'].describe()
# Out:
# count                   83878
# unique                     15
# top       2016-07-01 00:00:00
# freq                    10825
# first     2016-07-01 00:00:00
# last      2017-09-01 00:00:00
# Name: issue_d, dtype: object

# %% [markdown]
# The training set includes loans from June 2007 to June 2016. The test set includes loans from July 2016 to September 2017.

# %% [markdown]
# Now we can delete the `issue_d` variable, because it was not available before the loan was funded.

# %%
loans_train.drop('issue_d', axis=1, inplace=True)
loans_test.drop('issue_d', axis=1, inplace=True)

# %% [markdown]
# Now separate the predictor variables from the response variable:

# %%
X_train = loans_train.drop('charged_off', axis=1)
y_train = loans_train['charged_off']
X_test = loans_test.drop('charged_off', axis=1)
y_test = loans_test['charged_off']

# %%
del loans_train, loans_test

# %% [markdown]
# ## Imputation with mean substitution
# <a id="7.2"></a>

# %% [markdown]
# How complete is our training data?

# %%
missing_fractions = X_train.isnull().mean().sort_values(ascending=False)

# %%
missing_fractions[missing_fractions > 0]

# %% [markdown]
# We cannot have any missing data for the models that we'll train. Perform mean substitution, using only the means of the training set to prevent test set leakage.

# %%
from sklearn.preprocessing import Imputer

# %%
imputer = Imputer(copy=False)

# %%
imputer.fit(X_train)

# %%
X_train = pd.DataFrame(imputer.transform(X_train), columns=X_train.columns)
X_test  = pd.DataFrame(imputer.transform(X_test),  columns=X_test.columns)

# %% [markdown]
# ## Standardize the data
# <a id="7.3"></a>

# %% [markdown]
# Shift and scale each column individually so that it has zero mean and unit variance. This step is necessary to perform regularization.
#
# Train the scaler using only the training data to prevent test set leakage.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler(copy=False)

# %%
scaler.fit(X_train)

# %%
X_train = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
X_test  = pd.DataFrame(scaler.transform(X_test),  columns=X_test.columns)

# %% [markdown]
# # Statistical Modeling
# <a id="8"></a>

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## SGDClassifier

# %% [markdown]
# The SGDClassifier implements linear classifiers (SVM, logistic regression, a.o.) with SGD training. The linear classifier is chosen by the `loss` hyperparameter.

# %%
from sklearn.linear_model import SGDClassifier

# %%
model_sgdlogreg = SGDClassifier(loss='log', penalty='l1', max_iter=1000, tol=1e-3, random_state=1, warm_start=True)

# %%
model_sgdlogreg_cvscores = cross_val_score(estimator=model_sgdlogreg, X=X_train, y=y_train, scoring='roc_auc', cv=5, n_jobs=4, pre_dispatch=8)

# %%
print(model_sgdlogreg_cvscores)
print(model_sgdlogreg_cvscores.mean())

# %% [markdown]
# ## RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rfc = RandomForestClassifier(n_estimators=10, n_jobs=-1, random_state=1)

# %%
model_rfc_cvscores = cross_val_score(estimator=model_rfc, X=X_train, y=y_train, scoring='roc_auc', cv=5, n_jobs=4, pre_dispatch=8)

# %%
print(model_rfc_cvscores)
print(model_rfc_cvscores.mean())

# %% [markdown]
# ## Tune Hyperparameters of Chosen Model
# <a id="8.1"></a>

# %% [markdown]
# We're going to search through many hyperparameters of SGDClassifier using an exhaustive grid search with 3-fold cross-validation, implemented in GridSearchCV.
#
# Here are the hyperparameters that we'll try:

# %%
param_grid = {'alpha': [10.0**p for p in np.arange(-3.0, 2.5, 0.5)]}

# %% [markdown]
# Instantiate the grid estimator. We'll use the Matthews correlation coefficient as our scoring metric.

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_sgdlogreg = GridSearchCV(estimator=SGDClassifier(loss='log', penalty='l1', max_iter=1000, tol=1e-3, random_state=1, warm_start=True), param_grid=param_grid, scoring='roc_auc', n_jobs=4, pre_dispatch=8, cv=5, verbose=1)

# %% [markdown]
# Run the grid search (this could take some time).

# %%
grid_sgdlogreg.fit(X_train, y_train)

# %% [markdown]
# Hyperparameters that gave the best results on the hold out data:

# %%
grid_sgdlogreg.best_params_

# %% [markdown]
# Mean cross-validated AUCROC score of the best estimator:

# %%
grid_sgdlogreg.best_score_

# %% [markdown]
# Weights assigned to the features by the best estimator:

# %%
reg_coef = pd.Series(grid_sgdlogreg.best_estimator_.coef_[0], index=X_train.columns)

# %%
plt.figure(figsize=(6, 24), dpi=90)
sns.barplot(x=reg_coef.values, y=reg_coef.index, orient='h', color='darkblue')
plt.title('Logistic Regression Coefficients')
plt.xlabel('coefficient')
plt.ylabel('variable')

# %% [markdown]
# ## Test set evaluation
# <a id="8.2"></a>

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(y_test, grid_sgdlogreg.predict_proba(X_test)[:,1])

# %% [markdown]
# ## Linear Dependencies with Loan Status

# %%
linear_dep = pd.DataFrame()

# %%
for col in X_train.columns:
    linear_dep.loc[col, 'corr'] = X_train[col].corr(y_train)
linear_dep['abs_corr'] = abs(pearson_corr['corr'])

# %%
from sklearn.feature_selection import f_classif

# %%
for col in X_train.columns:
    mask = X_train[col].notnull()
    linear_dep.loc[col, 'F'], linear_dep.loc[col, 'p'] = f_classif(pd.DataFrame(X_train.loc[mask, col]), y_train.loc[mask])

# %%
linear_dep.sort_values('abs_corr', ascending=True, inplace=True)

# %%
linear_dep.iloc[-20:, [0,2,3]]
# Out:
#                                   corr             F    p
# sub_grade_B2                 -0.055223   2236.397864  0.0
# sub_grade_E1                  0.056529   2343.731745  0.0
# verification_status_Verified  0.056540   2344.706287  0.0
# sub_grade_B1                 -0.057400   2416.802596  0.0
# sub_grade_E5                  0.057718   2443.729458  0.0
# sub_grade_E4                  0.058985   2552.541431  0.0
# sub_grade_E3                  0.060043   2645.273355  0.0
# sub_grade_E2                  0.060711   2704.674296  0.0
# sub_grade_A3                 -0.062051   2825.878474  0.0
# sub_grade_A2                 -0.062767   2891.694037  0.0
# home_ownership_RENT           0.063576   2967.107649  0.0
# loan_amnt                     0.063598   2969.118688  0.0
# sub_grade_A5                 -0.066226   3220.711982  0.0
# sub_grade_A4                 -0.069089   3506.566794  0.0
# annual_inc                   -0.074252   4053.225270  0.0
# mort_acc                     -0.076676   4044.121007  0.0
# dti                           0.131005  12766.403302  0.0
# fico_range_high              -0.139927  14600.689446  0.0
# term                          0.188604  26965.820737  0.0
# int_rate                      0.256691  51570.855220  0.0

# %%
plt.figure(figsize=(6, 24), dpi=90)
sns.barplot(x=pearson_corr.values, y=pearson_corr.index, orient='h', color='darkblue')
plt.title('Pearson Correlations with Charge Off')
plt.xlabel('pearson correlation')
plt.ylabel('variable')
# Out:
# Text(0,0.5,'variable')

# %% [markdown]
# ## Mutual Information

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
mutual_info = pd.Series()
for col in X_train.columns:
    mask = X_train[col].notnull()
    mutual_info[col] = mutual_info_classif(pd.DataFrame(X_train.loc[mask, col]).sample(50000, random_state=1), y_train[mask].sample(50000, random_state=1), discrete_features=col not in ['int_rate', 'installment', 'annual_inc', 'dti'])

# %%
mutual_info.sort_values()
# Out:
# addr_state_IA                          [1.3877787807814457e-15]
# addr_state_DE                           [3.358910146463584e-08]
# addr_state_WI                            [3.35914729018838e-08]
# addr_state_NM                            [6.23348269685603e-08]
# addr_state_WY                           [8.094216261481102e-08]
# addr_state_AR                          [1.1984162123258868e-07]
# addr_state_AZ                           [3.107769801988236e-07]
# addr_state_MA                           [5.584396019636673e-07]
# home_ownership_OTHER                    [6.752138085863442e-07]
# addr_state_MN                           [1.430914754685375e-06]
# addr_state_KY                          [1.6981535194172948e-06]
# purpose_vacation                       [1.8596043553954777e-06]
# addr_state_ND                           [1.915822650507947e-06]
# purpose_renewable_energy               [2.1628548228507394e-06]
# addr_state_TX                          [2.2701281810200147e-06]
# addr_state_HI                          [5.4868380060220726e-06]
# home_ownership_OWN                      [5.728909600044574e-06]
# purpose_house                           [5.873267836275717e-06]
# addr_state_IL                           [6.756169174976234e-06]
# addr_state_KS                          [6.8295198226240444e-06]
# addr_state_ME                           [7.444939787795766e-06]
# addr_state_MO                           [8.198404816469468e-06]
# addr_state_MT                          [1.0353828011930993e-05]
# addr_state_NC                          [1.1039536111055737e-05]
# addr_state_VA                          [1.1132983160206528e-05]
# addr_state_IN                          [1.1586097579126264e-05]
# purpose_other                          [1.1808306722115025e-05]
# purpose_educational                     [1.299736074213706e-05]
# addr_state_MD                          [1.4316038835681527e-05]
# addr_state_NJ                           [1.636670883774921e-05]
# addr_state_NY                          [1.8236915789671126e-05]
# addr_state_MS                             [1.8421307634197e-05]
# purpose_major_purchase                 [1.9083728467449157e-05]
# addr_state_SC                           [2.014931236324173e-05]
# addr_state_MI                           [2.105858098051805e-05]
# addr_state_PA                          [2.1997529021600126e-05]
# purpose_medical                         [2.278383317124051e-05]
# addr_state_UT                          [2.2889010369569682e-05]
# sub_grade_C2                           [2.3259766858324538e-05]
# addr_state_VT                          [2.3972328391881972e-05]
# addr_state_OH                          [2.4396836942171263e-05]
# addr_state_CT                           [2.541509845516328e-05]
# addr_state_GA                           [2.580908400782317e-05]
# application_type_Joint App              [3.264019839193007e-05]
# addr_state_ID                           [3.395492649729218e-05]
# addr_state_RI                            [3.66464481715038e-05]
# addr_state_FL                           [3.687473810659592e-05]
# purpose_moving                          [4.092525423716499e-05]
# addr_state_OK                           [5.389065407742678e-05]
# addr_state_SD                          [5.5852357421941334e-05]
# addr_state_NE                           [6.310892325062795e-05]
# purpose_wedding                          [6.40638729569815e-05]
# addr_state_NH                            [6.79588305711994e-05]
# addr_state_CA                           [7.230393721921469e-05]
# addr_state_LA                            [7.48024299236788e-05]
# addr_state_OR                            [7.82130437594012e-05]
# addr_state_AL                           [8.243113437267705e-05]
# addr_state_WV                           [8.420846702283935e-05]
# addr_state_DC                            [8.48287075083348e-05]
# sub_grade_C3                            [9.067838182049565e-05]
# addr_state_TN                           [9.515601989268027e-05]
# addr_state_WA                           [9.710699176242524e-05]
# sub_grade_C1                           [0.00010174777083370862]
# addr_state_NV                          [0.00010500330401512839]
# purpose_home_improvement               [0.00011859779497624956]
# addr_state_CO                          [0.00016522032141984624]
# sub_grade_G3                           [0.00018275421169408265]
# sub_grade_G4                            [0.0002026481631223838]
# sub_grade_G5                           [0.00022469426487505082]
# emp_length                             [0.00023463017689939747]
# sub_grade_C4                            [0.0002617111694669591]
# sub_grade_B5                             [0.000271983785178391]
# verification_status_Source Verified    [0.00030138011533403786]
# sub_grade_G1                            [0.0003096469891248326]
# sub_grade_G2                            [0.0003266159283706804]
# purpose_small_business                 [0.00035060971119481657]
# sub_grade_C5                           [0.00042891393408562434]
# pub_rec_bankruptcies                   [0.00047216102238194566]
# sub_grade_F2                            [0.0005664697627692037]
# pub_rec                                 [0.0005847872906234615]
# sub_grade_B4                            [0.0006206098098424095]
# initial_list_status_w                   [0.0006282291184965816]
# sub_grade_F5                            [0.0006458011757146265]
# sub_grade_D1                            [0.0006732629600854703]
# purpose_debt_consolidation              [0.0007230153429588215]
# sub_grade_D2                            [0.0007675934335761581]
# sub_grade_F4                            [0.0007877834122189883]
# sub_grade_D3                            [0.0008940561797989646]
# purpose_credit_card                     [0.0009224229200129053]
# sub_grade_F3                            [0.0010283525743214408]
# sub_grade_E1                            [0.0012103629276734931]
# sub_grade_E5                              [0.00124836691949139]
# sub_grade_E4                            [0.0013969727359921628]
# sub_grade_D5                            [0.0014198804344073904]
# sub_grade_F1                            [0.0014217185693569563]
# sub_grade_E2                             [0.001449657971478939]
# sub_grade_B3                            [0.0014779695294664039]
# sub_grade_D4                            [0.0015254115430756929]
# sub_grade_B2                            [0.0015767424823702123]
# earliest_cr_line                        [0.0018546725459246624]
# verification_status_Verified            [0.0018565435688985554]
# annual_inc                               [0.001867425774414233]
# home_ownership_RENT                     [0.0019216917672373324]
# sub_grade_E3                            [0.0019550714070017267]
# sub_grade_B1                            [0.0020121796411414726]
# sub_grade_A2                            [0.0023005290032161486]
# sub_grade_A3                             [0.002715326427692998]
# sub_grade_A5                            [0.0029896741957148344]
# sub_grade_A4                            [0.0030211772780826245]
# mort_acc                                [0.0032973387044775765]
# mo_sin_old_il_acct                      [0.0054596679244439065]
# dti                                      [0.006266407705608934]
# mo_sin_old_rev_tl_op                       [0.0082445746621339]
# fico_range_high                          [0.010553116396199514]
# term                                     [0.016786129013081685]
# loan_amnt                                 [0.01913731575668296]
# installment                              [0.020448059608172864]
# int_rate                                  [0.03816625900065107]
# dtype: object
